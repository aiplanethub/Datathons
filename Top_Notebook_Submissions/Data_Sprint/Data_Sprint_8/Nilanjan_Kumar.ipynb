# %% [markdown]
# <a href="https://colab.research.google.com/github/dphi-official/Datathons/blob/master/Top_Notebook_Submissions/Data_Sprint/Data_Sprint_8/Nilanjan_Kumar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nilanjan Kumar
#
# ### LinkedIn profile - https://www.linkedin.com/in/nilanjan-kumar-05057b136/
#
# ### https://dphi.tech/practice/challenge/37#problem

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#importing ML libraries
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

#ignoring the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
audit_data  = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/audit_data/training_set_label.csv" )

# %%
audit_data.head()
# Out:
#    Sector_score LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  \
# 0          2.72           8    1.13      0.4   0.452    0.00      0.2   0.000
# 1          1.85          13    8.25      0.6   4.950    1.59      0.4   0.636
# 2          2.72          19    2.13      0.6   1.278    0.59      0.2   0.118
# 3         59.85          21    0.42      0.2   0.084    0.00      0.2   0.000
# 4          2.72           4    1.33      0.4   0.532    0.35      0.2   0.070
#
#    TOTAL  numbers  ...  RiSk_E  History  Prob  Risk_F  Score  Inherent_Risk  \
# 0   1.13      5.0  ...     0.4        0   0.2     0.0    2.2          1.852
# 1   9.84      5.0  ...     0.4        0   0.2     0.0    3.0          6.990
# 2   2.72      5.0  ...     0.4        0   0.2     0.0    2.4          2.948
# 3   0.42      5.0  ...     0.8        0   0.2     0.0    2.2          1.884
# 4   1.68      5.0  ...     0.4        0   0.2     0.0    2.2          2.002
#
#    CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# 0           0.4             0.5      0.3704     0
# 1           0.4             0.5      1.3980     1
# 2           0.4             0.5      0.5896     0
# 3           0.8             0.5      0.7536     0
# 4           0.4             0.5      0.4004     0
#
# [5 rows x 27 columns]

# %%
audit_data.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'Score_A', 'Risk_A', 'PARA_B',
#        'Score_B', 'Risk_B', 'TOTAL', 'numbers', 'Score_B.1', 'Risk_C',
#        'Money_Value', 'Score_MV', 'Risk_D', 'District_Loss', 'PROB', 'RiSk_E',
#        'History', 'Prob', 'Risk_F', 'Score', 'Inherent_Risk', 'CONTROL_RISK',
#        'Detection_Risk', 'Audit_Risk', 'Risk'],
#       dtype='object')

# %%
audit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 27 columns):
# Sector_score      543 non-null float64
# LOCATION_ID       543 non-null object
# PARA_A            543 non-null float64
# Score_A           543 non-null float64
# Risk_A            543 non-null float64
# PARA_B            543 non-null float64
# Score_B           543 non-null float64
# Risk_B            543 non-null float64
# TOTAL             543 non-null float64
# numbers           543 non-null float64
# Score_B.1         543 non-null float64
# Risk_C            543 non-null float64
# Money_Value       543 non-null float64
# Score_MV          543 non-null float64
# Risk_D            543 non-null float64
# District_Loss     543 non-null int64
# PROB              543 non-null float64
# RiSk_E            543 non-null float64
# History           543 non-null int64
# Prob              543 non-null float64
# Risk_F            543 non-null float64
# Score             543 non-null float64
# Inherent_Risk     543 non-null float64
# CONTROL_RISK      543 non-null float64
# Detection_Risk    543 non-null float64
# Audit_Risk        543 non-null float64
# Risk              543 non-null int64
# dtypes: float64(23), int64(3), object(1)
# memory usage: 114.6+ KB

# %%
audit_data.Risk.value_counts()
# Out:
# 0    330
# 1    213
# Name: Risk, dtype: int64

# %%
audit_data.LOCATION_ID.value_counts()
# Out:
# 8          54
# 19         51
# 16         37
# 9          34
# 5          32
# 12         31
# 2          30
# 6          28
# 4          24
# 15         23
# 13         20
# 11         18
# 32         17
# 29         14
# 14         13
# 22         13
# 18         11
# 39          9
# 1           7
# 27          7
# 43          7
# 31          7
# 21          7
# 25          6
# 37          5
# 20          5
# 28          4
# 38          4
# 7           3
# 3           3
# 40          3
# 36          3
# 30          3
# 35          2
# 17          1
# NUH         1
# 44          1
# SAFIDON     1
# 34          1
# 23          1
# 33          1
# 41          1
# Name: LOCATION_ID, dtype: int64

# %% [markdown]
# ### Deleting non significant variables

# %%
audit_data = audit_data.drop(['TOTAL','LOCATION_ID'],axis = 1)

# %%
audit_data.head()
# Out:
#    Sector_score  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  numbers  \
# 0          2.72    1.13      0.4   0.452    0.00      0.2   0.000      5.0
# 1          1.85    8.25      0.6   4.950    1.59      0.4   0.636      5.0
# 2          2.72    2.13      0.6   1.278    0.59      0.2   0.118      5.0
# 3         59.85    0.42      0.2   0.084    0.00      0.2   0.000      5.0
# 4          2.72    1.33      0.4   0.532    0.35      0.2   0.070      5.0
#
#    Score_B.1  Risk_C  ...  RiSk_E  History  Prob  Risk_F  Score  \
# 0        0.2     1.0  ...     0.4        0   0.2     0.0    2.2
# 1        0.2     1.0  ...     0.4        0   0.2     0.0    3.0
# 2        0.2     1.0  ...     0.4        0   0.2     0.0    2.4
# 3        0.2     1.0  ...     0.8        0   0.2     0.0    2.2
# 4        0.2     1.0  ...     0.4        0   0.2     0.0    2.2
#
#    Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# 0          1.852           0.4             0.5      0.3704     0
# 1          6.990           0.4             0.5      1.3980     1
# 2          2.948           0.4             0.5      0.5896     0
# 3          1.884           0.8             0.5      0.7536     0
# 4          2.002           0.4             0.5      0.4004     0
#
# [5 rows x 25 columns]

# %%
audit_data.describe()
# Out:
#        Sector_score      PARA_A     Score_A      Risk_A      PARA_B  \
# count    543.000000  543.000000  543.000000  543.000000  543.000000
# mean      20.464236    2.142874    0.346593    1.162339    9.480252
# std       24.441277    4.200770    0.173158    2.558306   22.445359
# min        1.850000    0.000000    0.200000    0.000000    0.000000
# 25%        2.370000    0.255000    0.200000    0.051000    0.000000
# 50%        3.890000    0.840000    0.200000    0.168000    0.460000
# 75%       55.570000    2.400000    0.600000    1.440000    4.500000
# max       59.850000   57.030000    0.600000   34.218000  144.390000
#
#           Score_B      Risk_B     numbers   Score_B.1      Risk_C  ...  \
# count  543.000000  543.000000  543.000000  543.000000  543.000000  ...
# mean     0.316022    5.538131    5.069982    0.223941    1.155617  ...
# std      0.171442   13.509523    0.281144    0.081145    0.549035  ...
# min      0.200000    0.000000    5.000000    0.200000    1.000000  ...
# 25%      0.200000    0.000000    5.000000    0.200000    1.000000  ...
# 50%      0.200000    0.092000    5.000000    0.200000    1.000000  ...
# 75%      0.400000    2.184000    5.000000    0.200000    1.000000  ...
# max      0.600000   86.634000    9.000000    0.600000    5.400000  ...
#
#            RiSk_E     History        Prob      Risk_F       Score  \
# count  543.000000  543.000000  543.000000  543.000000  543.000000
# mean     0.519337    0.086556    0.212891    0.044199    2.699448
# std      0.302349    0.534651    0.058735    0.309682    0.853460
# min      0.400000    0.000000    0.200000    0.000000    2.000000
# 25%      0.400000    0.000000    0.200000    0.000000    2.000000
# 50%      0.400000    0.000000    0.200000    0.000000    2.400000
# 75%      0.400000    0.000000    0.200000    0.000000    3.200000
# max      2.400000    9.000000    0.600000    5.400000    5.200000
#
#        Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk        Risk
# count     543.000000    543.000000           543.0  543.000000  543.000000
# mean       15.663949      0.563536             0.5    5.054067    0.392265
# std        43.195795      0.444976             0.0   13.394958    0.488705
# min         1.400000      0.400000             0.5    0.280000    0.000000
# 25%         1.582000      0.400000             0.5    0.316400    0.000000
# 50%         2.214000      0.400000             0.5    0.556000    0.000000
# 75%         9.959000      0.400000             0.5    3.032800    1.000000
# max       622.838000      5.800000             0.5  149.817600    1.000000
#
# [8 rows x 25 columns]

# %%
audit_data.isnull().sum()
# Out:
# Sector_score      0
# PARA_A            0
# Score_A           0
# Risk_A            0
# PARA_B            0
# Score_B           0
# Risk_B            0
# numbers           0
# Score_B.1         0
# Risk_C            0
# Money_Value       0
# Score_MV          0
# Risk_D            0
# District_Loss     0
# PROB              0
# RiSk_E            0
# History           0
# Prob              0
# Risk_F            0
# Score             0
# Inherent_Risk     0
# CONTROL_RISK      0
# Detection_Risk    0
# Audit_Risk        0
# Risk              0
# dtype: int64

# %%
X=audit_data.drop(['Risk'],axis=1)
Y = audit_data.Risk

# %%
corr = X.corr()
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r' & 'BrBG' are other good diverging colormaps
# Out:
# <style  type="text/css" >
#     #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col12 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col13 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col14 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col15 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col16 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col17 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col18 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col19 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col20 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col21 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col22 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row0_col23 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col12 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col13 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col14 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col15 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col16 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col17 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col18 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col19 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col20 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col21 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col22 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row1_col23 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row2_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row2_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row2_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row2_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row2_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row2_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row2_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row2_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row2_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row2_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row2_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_3ef8a78c_061a_11eb_86c9_84a93ea41a10row2_col11 {
#             background-color:  #000000;

# %%
X = X.drop(['Detection_Risk'],axis = 1)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 42)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train_scaled = pd.DataFrame(sc_X.fit_transform(X_train))
X_test_scaled = pd.DataFrame(sc_X.transform(X_test))

# %%
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import  accuracy_score, f1_score, precision_score,confusion_matrix, recall_score, roc_auc_score
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.svm import SVC 
plt.style.use('fivethirtyeight')

# %%
logi = LogisticRegression()
logi.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Cross Validation

# %%
kfold = model_selection.KFold(n_splits=10, random_state=7)
scoring = 'accuracy'

acc_logi = cross_val_score(estimator = logi, X = X_train_scaled, y = y_train, cv = kfold,scoring=scoring)
acc_logi.mean()
# Out:
# 0.9815789473684211

# %%
y_predict_logi = logi.predict(X_test_scaled)
acc= accuracy_score(y_test, y_predict_logi)
roc=roc_auc_score(y_test, y_predict_logi)
prec = precision_score(y_test, y_predict_logi)
rec = recall_score(y_test, y_predict_logi)
f1 = f1_score(y_test, y_predict_logi)

results = pd.DataFrame([['Logistic Regression',acc, acc_logi.mean(),prec,rec, f1,roc]],
               columns = ['Model', 'Accuracy','Cross Val Accuracy', 'Precision', 'Recall', 'F1 Score','ROC'])
results
# Out:
#                  Model  Accuracy  Cross Val Accuracy  Precision    Recall  \
# 0  Logistic Regression   0.96319            0.981579        1.0  0.913043
#
#    F1 Score       ROC
# 0  0.954545  0.956522

# %% [markdown]
# ## Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
kfold = model_selection.KFold(n_splits=10, random_state=7)
scoring = 'accuracy'

acc_logi = cross_val_score(estimator = dtc, X = X_train_scaled, y = y_train, cv = kfold,scoring=scoring)
acc_logi.mean()
# Out:
# 0.9973684210526315

# %%
y_predict_logi = dtc.predict(X_test_scaled)
acc= accuracy_score(y_test, y_predict_logi)
roc=roc_auc_score(y_test, y_predict_logi)
prec = precision_score(y_test, y_predict_logi)
rec = recall_score(y_test, y_predict_logi)
f1 = f1_score(y_test, y_predict_logi)

results = pd.DataFrame([['Decision Tree',acc, acc_logi.mean(),prec,rec, f1,roc]],
               columns = ['Model', 'Accuracy','Cross Val Accuracy', 'Precision', 'Recall', 'F1 Score','ROC'])
results
# Out:
#            Model  Accuracy  Cross Val Accuracy  Precision  Recall  F1 Score  \
# 0  Decision Tree       1.0            0.997368        1.0     1.0       1.0
#
#    ROC
# 0  1.0

# %% [markdown]
# ## Random Forest

# %%
random_forest_e = RandomForestClassifier()
random_forest_e.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier()

# %%
acc_rande = cross_val_score(estimator = random_forest_e, X = X_train_scaled, y = y_train, cv = kfold, scoring=scoring)
acc_rande.mean()
# Out:
# 0.9973684210526315

# %%
y_predict_r = random_forest_e.predict(X_test_scaled)
roc=roc_auc_score(y_test, y_predict_r)
acc = accuracy_score(y_test, y_predict_r)
prec = precision_score(y_test, y_predict_r)
rec = recall_score(y_test, y_predict_r)
f1 = f1_score(y_test, y_predict_r)

model_results = pd.DataFrame([['Random Forest',acc, acc_rande.mean(),prec,rec, f1,roc]],
               columns = ['Model', 'Accuracy','Cross Val Accuracy', 'Precision', 'Recall', 'F1 Score','ROC'])
results = results.append(model_results, ignore_index = True)
results
# Out:
#                  Model  Accuracy  Cross Val Accuracy  Precision    Recall  \
# 0  Logistic Regression  0.963190            0.981579        1.0  0.913043
# 1        Random Forest  0.993865            0.997368        1.0  0.985507
# 2        Random Forest  0.993865            0.997368        1.0  0.985507
#
#    F1 Score       ROC
# 0  0.954545  0.956522
# 1  0.992701  0.992754
# 2  0.992701  0.992754

# %%
ada_boost_e = AdaBoostClassifier()
ada_boost_e.fit(X_train_scaled, y_train)
# Out:
# AdaBoostClassifier()

# %%
acc_ada = cross_val_score(estimator = ada_boost_e, X = X_train_scaled, y = y_train, cv = kfold, scoring=scoring)
acc_ada.mean()
# Out:
# 0.9973684210526315

# %%
y_predict_r = ada_boost_e.predict(X_test_scaled)
roc=roc_auc_score(y_test, y_predict_r)
acc = accuracy_score(y_test, y_predict_r)
prec = precision_score(y_test, y_predict_r)
rec = recall_score(y_test, y_predict_r)
f1 = f1_score(y_test, y_predict_r)

model_results = pd.DataFrame([['Ada Boost',acc, acc_ada.mean(),prec,rec, f1,roc]],
               columns = ['Model', 'Accuracy','Cross Val Accuracy', 'Precision', 'Recall', 'F1 Score','ROC'])
results = results.append(model_results, ignore_index = True)
results
# Out:
#                  Model  Accuracy  Cross Val Accuracy  Precision    Recall  \
# 0  Logistic Regression  0.963190            0.981579        1.0  0.913043
# 1        Random Forest  0.993865            0.997368        1.0  0.985507
# 2        Random Forest  0.993865            0.997368        1.0  0.985507
# 3            Ada Boost  1.000000            0.997368        1.0  1.000000
#
#    F1 Score       ROC
# 0  0.954545  0.956522
# 1  0.992701  0.992754
# 2  0.992701  0.992754
# 3  1.000000  1.000000

# %% [markdown]
# ## ROC curve

# %%
from sklearn import metrics
import matplotlib.pyplot as plt

plt.figure()

# Add the models to the list that you want to view on the ROC plot
models = [
{
    'label': 'Logistic Regression',
    'model': LogisticRegression(),
},
    {
    'label': 'Random Forest Entropy',
    'model': RandomForestClassifier(n_estimators = 100,criterion='entropy', random_state = 47),
},
    
    
]

# Below for loop iterates through your models list
for m in models:
    model = m['model'] # select the model
    model.fit(X_train_scaled, y_train) # train the model
    y_pred=model.predict(X_test_scaled) # predict the test data
# Compute False postive rate, and True positive rate
    fpr, tpr, thresholds = metrics.roc_curve(y_test, model.predict_proba(X_test_scaled)[:,1])
# Calculate Area under the curve to display on the plot
    auc = metrics.roc_auc_score(y_test,model.predict(X_test_scaled))
# Now, plot the computed values
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (m['label'], auc))
# Custom settings for the plot 
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('1-Specificity(False Positive Rate)')
plt.ylabel('Sensitivity(True Positive Rate)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Confusion Matrix

# %%
import seaborn as sns

cm_logi = confusion_matrix(y_test, y_predict_logi)
plt.title('Confusion matrix of the Logistic classifier')
sns.heatmap(cm_logi,annot=True,fmt="d")
plt.show()

# %%
cm_r = confusion_matrix(y_test, y_predict_r)
plt.title('Confusion matrix of the Random Forest classifier')
sns.heatmap(cm_r,annot=True,fmt="d")
plt.show()

# %%
from sklearn.feature_selection import SelectFromModel
sel = SelectFromModel(RandomForestClassifier(n_estimators = 100,criterion='entropy', random_state = 47))
sel.fit(X_train_scaled, y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(criterion='entropy',
#                                                  random_state=47))

# %%
select_X_train = sel.transform(X_train_scaled)
select_X_test = sel.transform(X_test_scaled) 

# train model
#selection_model = XGBClassifier()
selection_model1 = RandomForestClassifier(n_estimators = 100,criterion='entropy', random_state = 47)
selection_model1.fit(select_X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=47)

# %%
rfc_prd1 = selection_model1.predict(select_X_test)

# %%
print(confusion_matrix(y_test, rfc_prd1 ))
print(round(accuracy_score(y_test, rfc_prd1),2)*100)
# Out:
# [[94  0]
#  [ 0 69]]
# 100.0

# %% [markdown]
# ## Working on Test data

# %%
test_data = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/audit_data/testing_set_label.csv')

# %%
test_data.head()
# Out:
#    Sector_score LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  \
# 0          3.89          22    0.00      0.2   0.000   18.05      0.6  10.830
# 1         55.57          29    1.26      0.4   0.504    1.58      0.4   0.632
# 2          2.72          16    0.00      0.2   0.000    0.00      0.2   0.000
# 3         59.85           4    0.00      0.2   0.000    0.00      0.2   0.000
# 4          3.41          16   11.73      0.6   7.038   85.87      0.6  51.522
#
#    TOTAL  numbers  ...  PROB  RiSk_E  History  Prob  Risk_F  Score  \
# 0  18.05      5.0  ...   0.2     0.4        0   0.2     0.0    3.2
# 1   2.84      5.0  ...   0.2     0.4        0   0.2     0.0    3.0
# 2   0.00      5.0  ...   0.2     0.8        0   0.2     0.0    2.2
# 3   0.00      5.0  ...   0.2     0.4        0   0.2     0.0    2.0
# 4  97.60      5.0  ...   0.2     0.4        1   0.4     0.4    4.0
#
#    Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk
# 0         12.688           0.4             0.5      2.5376
# 1          5.136           0.4             0.5      1.0272
# 2          1.800           0.8             0.5      0.7200
# 3          1.400           0.4             0.5      0.2800
# 4         63.144           0.8             0.5     25.2576
#
# [5 rows x 26 columns]

# %%
test_data.isnull().sum()
# Out:
# Sector_score      0
# LOCATION_ID       0
# PARA_A            0
# Score_A           0
# Risk_A            0
# PARA_B            0
# Score_B           0
# Risk_B            0
# TOTAL             0
# numbers           0
# Score_B.1         0
# Risk_C            0
# Money_Value       1
# Score_MV          0
# Risk_D            0
# District_Loss     0
# PROB              0
# RiSk_E            0
# History           0
# Prob              0
# Risk_F            0
# Score             0
# Inherent_Risk     0
# CONTROL_RISK      0
# Detection_Risk    0
# Audit_Risk        0
# dtype: int64

# %%
test_data['Money_Value'].fillna((test_data['Money_Value'].median()), inplace=True)

# %%
test_data.isnull().sum()
# Out:
# Sector_score      0
# LOCATION_ID       0
# PARA_A            0
# Score_A           0
# Risk_A            0
# PARA_B            0
# Score_B           0
# Risk_B            0
# TOTAL             0
# numbers           0
# Score_B.1         0
# Risk_C            0
# Money_Value       0
# Score_MV          0
# Risk_D            0
# District_Loss     0
# PROB              0
# RiSk_E            0
# History           0
# Prob              0
# Risk_F            0
# Score             0
# Inherent_Risk     0
# CONTROL_RISK      0
# Detection_Risk    0
# Audit_Risk        0
# dtype: int64

# %%
test_data = test_data.drop(['TOTAL','LOCATION_ID','Detection_Risk'],axis = 1)

# %%
test_data.head()
# Out:
#    Sector_score  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  numbers  \
# 0          3.89    0.00      0.2   0.000   18.05      0.6  10.830      5.0
# 1         55.57    1.26      0.4   0.504    1.58      0.4   0.632      5.0
# 2          2.72    0.00      0.2   0.000    0.00      0.2   0.000      5.0
# 3         59.85    0.00      0.2   0.000    0.00      0.2   0.000      5.0
# 4          3.41   11.73      0.6   7.038   85.87      0.6  51.522      5.0
#
#    Score_B.1  Risk_C  ...  District_Loss  PROB  RiSk_E  History  Prob  Risk_F  \
# 0        0.2     1.0  ...              2   0.2     0.4        0   0.2     0.0
# 1        0.2     1.0  ...              2   0.2     0.4        0   0.2     0.0
# 2        0.2     1.0  ...              4   0.2     0.8        0   0.2     0.0
# 3        0.2     1.0  ...              2   0.2     0.4        0   0.2     0.0
# 4        0.2     1.0  ...              2   0.2     0.4        1   0.4     0.4
#
#    Score  Inherent_Risk  CONTROL_RISK  Audit_Risk
# 0    3.2         12.688           0.4      2.5376
# 1    3.0          5.136           0.4      1.0272
# 2    2.2          1.800           0.8      0.7200
# 3    2.0          1.400           0.4      0.2800
# 4    4.0         63.144           0.8     25.2576
#
# [5 rows x 23 columns]

# %%
sc = StandardScaler()
test_data_scaled = pd.DataFrame(sc.fit_transform(test_data))

# %%
yprd5 = dtc.predict(test_data_scaled)

# %%
res = pd.DataFrame(yprd5) #target is nothing but the final predictions of your model on input features of your new unseen test data
 
res.columns = ["prediction"]
res.to_csv("submission_dtc.csv")

# %%
yprd2 = logi.predict(test_data_scaled)

# %%
res = pd.DataFrame(yprd2) #target is nothing but the final predictions of your model on input features of your new unseen test data
 
res.columns = ["prediction"]
res.to_csv("submission.csv")

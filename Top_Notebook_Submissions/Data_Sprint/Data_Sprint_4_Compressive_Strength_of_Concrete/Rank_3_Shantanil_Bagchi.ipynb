# %% [markdown]
# <a href="https://colab.research.google.com/github/dphi-official/Datathons/blob/master/Top_Notebook_Submissions/Data_Sprint/Data_Sprint_4/Rank_3_Shantanil_Bagchi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [Data Sprint 4](https://dphi.tech/practice/challenge/28) (Compressive Strength of Concrete)
#
# #### **Prepared by - Shantanil Bagchi**

# %% [markdown]
# ### Objective
# The concrete compressive strength is a highly nonlinear function of age and ingredients. These ingredients include cement, blast furnace slag, fly ash, water, superplasticizer, coarse aggregate, and fine aggregate. Your objective is to build a machine learning model that would help Civil Engineers to estimate the compressive strength of the concrete and they can further take a decision whether the concrete should be used in their current project or not.
#
#
# ### Attribute information
# - Cement (component 1) -- quantitative -- kg in a m3 mixture -- Input Variable
# - Blast Furnace Slag (component 2) -- quantitative -- kg in a m3 mixture -- Input Variable
# - Fly Ash (component 3) -- quantitative -- kg in a m3 mixture -- Input Variable
# - Water (component 4) -- quantitative -- kg in a m3 mixture -- Input Variable
# - Superplasticizer (component 5) -- quantitative -- kg in a m3 mixture -- Input Variable
# - Coarse Aggregate (component 6) -- quantitative -- kg in a m3 mixture -- Input Variable
# - Fine Aggregate (component 7) -- quantitative -- kg in a m3 mixture -- Input Variable
# - Age -- quantitative -- Day (1~365) -- Input Variable
# - Concrete compressive strength -- quantitative -- MPa(megapascals) -- Output Variable
#
# <hr><hr>

# %% [markdown]
# ### Importing the necessary libraries for EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pprint
from scipy import stats
# %matplotlib inline
pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# ### Load the Dataset

# %%
data  = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/concrete_data/training_set_label.csv" )

# %% [markdown]
# ### Data-first few rows

# %%
data.head()
# Out:
#    Cement (component 1)(kg in a m^3 mixture)  \
# 0                                     298.20
# 1                                     397.00
# 2                                     251.37
# 3                                     304.00
# 4                                     297.00
#
#    Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
# 3                                              140.0
# 4                                                0.0
#
#    Fly Ash (component 3)(kg in a m^3 mixture)  \
# 0                                      107.00
# 1                                        0.00
# 2                                      118.27
# 3                                        0.00
# 4                                        0.00
#
#    Water  (component 4)(kg in a m^3 mixture)  \
# 0                                     209.70
# 1                                     186.00
# 2                                     188.45
# 3                                     214.00
# 4                                     186.00
#
#    Superplasticizer (component 5)(kg in a m^3 mixture)  \
# 0                                              11.10
# 1                                               0.00
# 2                                               6.35
# 3                                               6.00
# 4                                               0.00
#
#    Coarse Aggregate  (component 6)(kg in a m^3 mixture)  \
# 0                                              879.6
# 1                                             1040.0
# 2                                             1028.4
# 3                                              895.0
# 4                                             1040.0
#
#    Fine Aggregate (component 7)(kg in a m^3 mixture)  Age (day)  \
# 0                                             744.20         28
# 1                                             734.00         28
# 2                                             757.73         56
# 3                                             722.00         28
# 4                                             734.00          7
#
#    Concrete compressive strength(MPa, megapascals)
# 0                                         31.875165
# 1                                         36.935229
# 2                                         36.638755
# 3                                         33.418902
# 4                                         30.957472

# %% [markdown]
# ### Changing Column Names for Easy Access

# %%
data.columns=['Cement',
       'Blast_Furnace_Slag',
       'Fly_Ash',
       'Water',
       'Superplasticizer',
       'Coarse_Aggregate',
       'Fine_Aggregate', 'Age',
       'Concrete_compressive_strength']

# %% [markdown]
# ### Data Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 772 entries, 0 to 771
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Cement                         772 non-null    float64
#  1   Blast_Furnace_Slag             772 non-null    float64
#  2   Fly_Ash                        772 non-null    float64
#  3   Water                          772 non-null    float64
#  4   Superplasticizer               772 non-null    float64
#  5   Coarse_Aggregate               772 non-null    float64
#  6   Fine_Aggregate                 772 non-null    float64
#  7   Age                            772 non-null    int64
#  8   Concrete_compressive_strength  772 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 54.4 KB

# %% [markdown]
# ### Missing Values

# %%
print (data.isnull().sum())
# Out:
# Cement                           0
# Blast_Furnace_Slag               0
# Fly_Ash                          0
# Water                            0
# Superplasticizer                 0
# Coarse_Aggregate                 0
# Fine_Aggregate                   0
# Age                              0
# Concrete_compressive_strength    0
# dtype: int64

# %% [markdown]
# ### Creating Interaction Term

# %%
data['Water_Cement_ratio']=data['Water']/data['Cement']
#data['Water_Binder_ratio']=data['Water']/(data['Cement']+data['Blast_Furnace_Slag']+data['Fly_Ash'])

# %% [markdown]
# ### Data Summary

# %%
plt.figure(figsize=(12,8))
sns.heatmap(round(data.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f",cmap="YlGnBu")
plt.xticks(fontsize=20)
plt.yticks(fontsize=12)
plt.title("Variables summary")
plt.show()

# %% [markdown]
# ### Histogram of the complete dataset

# %%
# Distplot
fig, ax2 = plt.subplots(3, 3, figsize=(16, 16))
sns.distplot(data['Cement'],ax=ax2[0][0])
sns.distplot(data['Blast_Furnace_Slag'],ax=ax2[0][1])
sns.distplot(data['Fly_Ash'],ax=ax2[0][2])
sns.distplot(data['Water'],ax=ax2[1][0])
sns.distplot(data['Superplasticizer'],ax=ax2[1][1])
sns.distplot(data['Coarse_Aggregate'],ax=ax2[1][2])
sns.distplot(data['Fine_Aggregate'],ax=ax2[2][0])
sns.distplot(data['Age'],ax=ax2[2][1])
sns.distplot(data['Concrete_compressive_strength'],ax=ax2[2][2])

# %% [markdown]
# ### **Key Insights**
# - cement is almost normal.
# - slag has two/three gausssians and rightly skewed.
# - ash has two gaussians and rightly skewed.
# - water has three guassians and slighly left skewed.
# - superplastic has two gaussians and rightly skewed.
# - coarseagg has three guassians and almost normal.
# - fineagg has almost two guassians and looks like normal.
# - age has multiple guassians and rightly skewed.

# %% [markdown]
# ### Skewness Degree

# %%
from scipy.stats import skew
numerical_features = data.select_dtypes(include=[np.number]).columns
categorical_features = data.select_dtypes(include=[np.object]).columns
skew_values = skew(data[numerical_features], nan_policy = 'omit')
dummy = pd.concat([pd.DataFrame(list(numerical_features), columns=['Features']), 
           pd.DataFrame(list(skew_values), columns=['Skewness degree'])], axis = 1)
dummy.sort_values(by = 'Skewness degree' , ascending = False)
# Out:
#                         Features  Skewness degree
# 7                            Age         3.241385
# 4               Superplasticizer         0.928785
# 9             Water_Cement_ratio         0.926699
# 1             Blast_Furnace_Slag         0.761623
# 2                        Fly_Ash         0.567073
# 0                         Cement         0.502577
# 8  Concrete_compressive_strength         0.423727
# 3                          Water        -0.011328
# 5               Coarse_Aggregate        -0.047778
# 6                 Fine_Aggregate        -0.229588

# %%
data.groupby("Age").mean()
# Out:
#          Cement  Blast_Furnace_Slag     Fly_Ash       Water  Superplasticizer  \
# Age
# 1    442.500000            0.000000    0.000000  193.000000          0.000000
# 3    289.870833           62.616250   56.353438  177.159792          6.427781
# 7    305.248421           95.316842   11.084211  184.521053          2.906737
# 14   254.645882           17.684902   94.092941  175.267843          6.548569
# 28   263.118476           91.836381   60.614127  184.016444          6.793387
# 56   300.667971           59.581159   83.109855  167.326667          9.948362
# 90   282.437209           91.281395    0.000000  202.209302          0.000000
# 91   398.364706          145.876471    0.000000  157.288235         15.723529
# 100  219.536750           25.976750  114.893500  170.550750          7.795425
# 120  331.000000            0.000000    0.000000  192.000000          0.000000
# 180  328.033333           47.490476    0.000000  204.952381          0.000000
# 270  380.700000           60.800000    0.000000  215.800000          0.000000
# 360  242.200000           69.800000    0.000000  191.666667          0.000000
# 365  326.611111           87.611111    0.000000  221.222222          0.000000
#
#      Coarse_Aggregate  Fine_Aggregate  Concrete_compressive_strength  \
# Age
# 1         1045.500000      688.000000                       9.452716
# 3          975.625104      795.776979                      18.572608
# 7          983.737895      770.676842                      24.776786
# 14        1021.122157      797.314314                      29.379519
# 28         953.408032      761.004540                      36.483745
# 56         974.894493      799.110725                      52.997665
# 90         960.948837      754.009302                      40.052912
# 91         927.705882      790.976471                      69.780244
# 100       1024.464750      806.227000                      47.436466
# 120       1025.000000      821.000000                      39.382869
# 180        987.114286      733.495238                      42.003699
# 270        989.900000      637.700000                      54.485220
# 360        995.000000      837.633333                      38.837953
# 365        940.000000      661.555556                      43.001163
#
#      Water_Cement_ratio
# Age
# 1              0.441558
# 3              0.711862
# 7              0.698620
# 14             0.739179
# 28             0.820327
# 56             0.628487
# 90             0.848302
# 91             0.404469
# 100            0.802711
# 120            0.580060
# 180            0.696704
# 270            0.637323
# 360            0.894748
# 365            0.729966

# %%
data.Age.value_counts()
# Out:
# 28     315
# 3       96
# 7       95
# 56      69
# 14      51
# 90      43
# 100     40
# 180     21
# 91      17
# 270     10
# 365      9
# 360      3
# 1        2
# 120      1
# Name: Age, dtype: int64

# %% [markdown]
# ### Visualise the interactions between terms

# %%
sns.pairplot(data)

# %% [markdown]
# <hr><hr>
#
# ### Further Analysis

# %%
# Distplot
fig, ax2 = plt.subplots(2,4, figsize=(20, 10))
sns.regplot('Concrete_compressive_strength','Cement',data=data,ax=ax2[0][0])
sns.regplot('Concrete_compressive_strength','Blast_Furnace_Slag',data=data,ax=ax2[0][1])
sns.regplot('Concrete_compressive_strength','Fly_Ash',data=data,ax=ax2[0][2])
sns.regplot('Concrete_compressive_strength','Water',data=data,ax=ax2[0][3])
sns.regplot('Concrete_compressive_strength','Superplasticizer',data=data,ax=ax2[1][0])
sns.regplot('Concrete_compressive_strength','Coarse_Aggregate',data=data,ax=ax2[1][1])
sns.regplot('Concrete_compressive_strength','Fine_Aggregate',data=data,ax=ax2[1][2])
sns.regplot('Concrete_compressive_strength','Age',data=data,ax=ax2[1][3])
#sns.regplot('Concrete_compressive_strength','Water_Cement_ratio',data=data,ax=ax2[0][0])
#sns.regplot('Concrete_compressive_strength','Water_Binder_ratio',data=data,ax=ax2[2][1])

# %% [markdown]
# #### Strength attribute : Relationship between dependent and independent attributes
# strength: Now its comparing the target column with all other independent attributes and its showing us very vital information.
#
# - strength vs cement: It is linearly related to the cement. The relationship is positive and we can see that for a given value of cement we have a multiple values of strength. Hence Cement though it has positive relationship with the strength, it is not a very good predictor.
# - strength vs slag: There is no particular trend.
# - strength vs age: For a given value of age, we have different values of strength. Hence, It is not a good predictor.
# - strength vs superplastic:For a given value of age, we have different values of strength. Hence, It is not a good predictor.
# - Other attributes does not give any strong relationship with strength.
# Hence, we can see that none of the independent attributes are a good predictors of the strength attribute. There is a no linear relationship between them.
#
# So, we will not use Linear model

# %% [markdown]
# ### Heatmap to see correlation

# %%
plt.figure(figsize=(20,7))
sns.heatmap(data.corr(), annot=True)

# %% [markdown]
# ### Dropping Water and Cement Columns

# %%
data=data[['Superplasticizer',
       'Coarse_Aggregate', 'Fine_Aggregate', 'Age', 'Water_Cement_ratio',
       'Blast_Furnace_Slag', 'Fly_Ash',
       'Concrete_compressive_strength']]

# %%
cor = data.corr()

mask = np.zeros_like(cor)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(12,10))

with sns.axes_style("white"):
    sns.heatmap(cor,annot=True,linewidth=2,
                mask = mask,cmap="YlGnBu")
plt.title("Correlation between variables")
plt.show()

# %% [markdown]
# ### Outlier Detection

# %%
outlier_list=[]
for c in data.columns[:-1]:
    Q1=data[c].quantile(q=0.25)
    Q3=data[c].quantile(q=0.75)
    print ("***************************************************************************")
    print('OUTLIER DETECTION FOR',c.upper())
    print ("***************************************************************************")
    
    print('1st Quartile (Q1) is: ', Q1)
    print('3st Quartile (Q3) is: ', Q3)
    print('Interquartile range (IQR) is ', stats.iqr(data[c]))
    L_outliers=Q1-1.5*(Q3-Q1)
    U_outliers=Q3+1.5*(Q3-Q1)
    print('Lower outliers in',c, L_outliers)
    print('Upper outliers in ',c, U_outliers)
    print ("***************************************************************************")
    print('Number of outliers in',c, 'upper : ', data[data[c]>U_outliers][c].count())
    print('Number of outliers in',c,' lower : ', data[data[c]<L_outliers][c].count())
    print('% of Outlier in ',c,' upper: ',round(data[data[c]>U_outliers][c].count()*100/len(data)), '%')
    print('% of Outlier in ',c,' lower: ',round(data[data[c]<L_outliers][c].count()*100/len(data)), '%')
    print ("***************************************************************************")
    print(data[  (data[c] < L_outliers) | (data[c] > U_outliers)  ].index)
    outlier_list.extend(data[  (data[c] < L_outliers) | (data[c] > U_outliers)  ].index)
    print('\n')
# Out:
# ***************************************************************************
# OUTLIER DETECTION FOR SUPERPLASTICIZER
# ***************************************************************************
# 1st Quartile (Q1) is:  0.0
# 3st Quartile (Q3) is:  10.025
# Interquartile range (IQR) is  10.025
# Lower outliers in Superplasticizer -15.037500000000001
# Upper outliers in  Superplasticizer 25.0625
# ***************************************************************************
# Number of outliers in Superplasticizer upper :  7
# Number of outliers in Superplasticizer  lower :  0
# % of Outlier in  Superplasticizer  upper:  1.0 %
# % of Outlier in  Superplasticizer  lower:  0.0 %
# ***************************************************************************
# Int64Index([119, 290, 334, 505, 600, 676, 708], dtype='int64')
#
#
# ***************************************************************************
# OUTLIER DETECTION FOR COARSE_AGGREGATE
# ***************************************************************************
# 1st Quartile (Q1) is:  932.0
# 3st Quartile (Q3) is:  1028.1
# Interquartile range (IQR) is  96.09999999999991
# Lower outliers in Coarse_Aggregate 787.8500000000001
# Upper outliers in  Coarse_Aggregate 1172.2499999999998
# ***************************************************************************
# Number of outliers in Coarse_Aggregate upper :  0
# Number of outliers in Coarse_Aggregate  lower :  0
# % of Outlier in  Coarse_Aggregate  upper:  0.0 %
# % of Outlier in  Coarse_Aggregate  lower:  0.0 %
# ***************************************************************************
# Int64Index([], dtype='int64')
#
#
# ***************************************************************************
# OUTLIER DETECTION FOR FINE_AGGREGATE
# ***************************************************************************
# 1st Quartile (Q1) is:  724.3
# 3st Quartile (Q3) is:  821.0
# Interquartile range (IQR) is  96.70000000000005
# Lower outliers in Fine_Aggregate 579.2499999999999
# Upper outliers in  Fine_Aggregate 966.0500000000001
# ***************************************************************************
# Number of outliers in Fine_Aggregate upper :  3
# Number of outliers in Fine_Aggregate  lower :  0
# % of Outlier in  Fine_Aggregate  upper:  0.0 %
# % of Outlier in  Fine_Aggregate  lower:  0.0 %
# ***************************************************************************
# Int64Index([393, 598, 693], dtype='int64')
#
#
# ***************************************************************************
# OUTLIER DETECTION FOR AGE
# ***************************************************************************
# 1st Quartile (Q1) is:  12.25
# 3st Quartile (Q3) is:  56.0
# Interquartile range (IQR) is  43.75
# Lower outliers in Age -53.375
# Upper outliers in  Age 121.625
# ***************************************************************************
# Number of outliers in Age upper :  43
# Number of outliers in Age  lower :  0
# % of Outlier in  Age  upper:  6.0 %
# % of Outlier in  Age  lower:  0.0 %
# ***************************************************************************
# Int64Index([  9,  18,  22,  39,  41,  61,  79,  82, 121, 138, 145, 148, 152,
#             163, 199, 205, 241, 281, 293, 324, 333, 335, 388, 391, 417, 421,
#             431, 448, 468, 473, 477, 487, 525, 552, 585, 625, 631, 635, 652,
#             653, 720, 724, 730],
#            dtype='int64')
#
#
# ***************************************************************************
# OUTLIER DETECTION FOR WATER_CEMENT_RATIO
# ***************************************************************************
# 1st Quartile (Q1) is:  0.5333333333333333
# 3st Quartile (Q3) is:  0.9494641004955631
# Interquartile range (IQR) is  0.41613076716222974
# Lower outliers in Water_Cement_ratio -0.09086281741001134
# Upper outliers in  Water_Cement_ratio 1.5736602512389077
# ***************************************************************************
# Number of outliers in Water_Cement_ratio upper :  12
# Number of outliers in Water_Cement_ratio  lower :  0
# % of Outlier in  Water_Cement_ratio  upper:  2.0 %
# % of Outlier in  Water_Cement_ratio  lower:  0.0 %
# ***************************************************************************
# Int64Index([30, 129, 187, 277, 451, 509, 612, 613, 659, 687, 714, 751], dtype='int64')
#
#
# ***************************************************************************
# OUTLIER DETECTION FOR BLAST_FURNACE_SLAG
# ***************************************************************************
# 1st Quartile (Q1) is:  0.0
# 3st Quartile (Q3) is:  144.77499999999998
# Interquartile range (IQR) is  144.77499999999998
# Lower outliers in Blast_Furnace_Slag -217.16249999999997
# Upper outliers in  Blast_Furnace_Slag 361.93749999999994
# ***************************************************************************
# Number of outliers in Blast_Furnace_Slag upper :  0
# Number of outliers in Blast_Furnace_Slag  lower :  0
# % of Outlier in  Blast_Furnace_Slag  upper:  0.0 %
# % of Outlier in  Blast_Furnace_Slag  lower:  0.0 %
# ***************************************************************************
# Int64Index([], dtype='int64')
#
#
# ***************************************************************************
# OUTLIER DETECTION FOR FLY_ASH
# ***************************************************************************
# 1st Quartile (Q1) is:  0.0
# 3st Quartile (Q3) is:  118.1875
# Interquartile range (IQR) is  118.1875
# Lower outliers in Fly_Ash -177.28125
# Upper outliers in  Fly_Ash 295.46875
# ***************************************************************************
# Number of outliers in Fly_Ash upper :  0
# Number of outliers in Fly_Ash  lower :  0
# % of Outlier in  Fly_Ash  upper:  0.0 %
# % of Outlier in  Fly_Ash  lower:  0.0 %
# ***************************************************************************
# Int64Index([], dtype='int64')

# %%
data.loc[list(set(outlier_list))]
# Out:
#      Superplasticizer  Coarse_Aggregate  Fine_Aggregate  Age  \
# 129               0.0             938.2           849.0   28
# 388               0.0             932.0           594.0  365
# 391               0.0             932.0           594.0  180
# 393              23.4             852.1           992.6   91
# 9                 0.0            1047.0           806.9  360
# ..                ...               ...             ...  ...
# 625               0.0            1125.0           613.0  270
# 119              28.2             852.1           893.7   91
# 121               0.0             932.0           594.0  365
# 635               0.0             932.0           670.0  180
# 509               0.0             958.2           800.1   90
#
#      Water_Cement_ratio  Blast_Furnace_Slag  Fly_Ash  \
# 129            1.879040               162.4      0.0
# 388            0.600000                95.0      0.0
# 391            0.600000                95.0      0.0
# 393            0.337600                93.8      0.0
# 9              1.375358               209.4      0.0
# ..                  ...                 ...      ...
# 625            0.360000                 0.0      0.0
# 119            0.266893                 0.0      0.0
# 121            0.685714               142.5      0.0
# 635            1.200000               190.0      0.0
# 509            1.659869               183.9      0.0
#
#      Concrete_compressive_strength
# 129                      20.593959
# 388                      43.698299
# 391                      40.759063
# 393                      62.500999
# 9                        44.698040
# ..                             ...
# 625                      67.113594
# 119                      59.198409
# 121                      41.052780
# 635                      46.931942
# 509                      33.192064
#
# [65 rows x 8 columns]

# %%
data_outlier=data.drop(outlier_list,axis=0).reset_index(drop = True)

# %% [markdown]
# <hr><hr>
#
# ### Applying ML Method

# %%
# Input/independent variables
X = data.drop('Concrete_compressive_strength', axis = 1)   # here we are droping the output feature as this is the target and 'X' is input features, the changes are not 
                                              # made inplace as we have not used 'inplace = True'
y = data['Concrete_compressive_strength'] 

#############################################################################
#X_outlier = data_outlier.drop('Concrete_compressive_strength', axis = 1)
#y_outlier = data_outlier['Concrete_compressive_strength'] 

#################################################################################
#X_reduced = data.drop( ['Concrete_compressive_strength','Coarse_Aggregate','Fine_Aggregate'] , axis=1)
#y_reduced = data['Concrete_compressive_strength'] 

###################################################################################
#X_reduced_water_cement= data.drop( ['Concrete_compressive_strength','Water','Cement'] , axis=1)
#y_reduced_water_cement = data['Concrete_compressive_strength'] 

#######################################################################################
#X_reduced_water_binder = data.drop( ['Concrete_compressive_strength','Fly_Ash','Water','Cement','Blast_Furnace_Slag'] , axis=1)
#y_reduced_water_binder = data['Concrete_compressive_strength'] 

#X_original = data.drop(['Concrete_compressive_strength','Water_Cement_ratio'], axis = 1)   # here we are droping the output feature as this is the target and 'X' is input features, the changes are not 
                                              # made inplace as we have not used 'inplace = True'
#y_original = data['Concrete_compressive_strength']

# %%
from sklearn.model_selection import  train_test_split, cross_val_score
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
#X_train_or, X_test_or, y_train_or, y_test_or = train_test_split(X_original, y_original, test_size = 0.25,random_state=101)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25,random_state=2)
#X_train_out, X_test_out, y_train_out, y_test_out= train_test_split(X_outlier, y_outlier, test_size = 0.25,random_state=101)
#X_train_red, X_test_red, y_train_red, y_test_red = train_test_split(X_reduced, y_reduced, test_size = 0.25,random_state=101)
#X_train_wc, X_test_wc, y_train_wc, y_test_wc = train_test_split(X_reduced_water_cement, y_reduced_water_cement, test_size = 0.25,random_state=101)
#X_train_wb, X_test_wb, y_train_wb, y_test_wb = train_test_split(X_reduced_water_binder, y_reduced_water_binder, test_size = 0.2,random_state=42)

# %% [markdown]
# ## Model

# %%
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from scipy.stats import pearsonr
warnings.filterwarnings("ignore")
#sns.set(style="darkgrid", color_codes=True) 

target = "Concrete_compressive_strength"
def model(algorithm,dtrainx,dtrainy,dtestx,dtesty,of_type,plot=False):
    
    print (algorithm)
    print ("***************************************************************************")
    algorithm.fit(dtrainx,dtrainy)
    
    #print(algorithm.get_params(deep=True))
    
    prediction = algorithm.predict(dtestx)
    
    print ("ROOT MEAN SQUARED ERROR :", np.sqrt(mean_squared_error(dtesty,prediction)) )
    print ("***************************************************************************")
    
    print ('Performance on training data :', algorithm.score(dtrainx,dtrainy)*100)
    print ('Performance on testing data :', algorithm.score(dtestx,dtesty)*100)
    #print('Accuracy : ',metrics.r2_score(dtesty,prediction)*100)
    print ("***************************************************************************")
    if plot==True:
        sns.jointplot(x=dtesty, y=prediction, stat_func=pearsonr,kind="reg", color="k") 
    
       
    prediction = pd.DataFrame(prediction)
    cross_val = cross_val_score(algorithm,dtrainx,dtrainy,cv=10)#,scoring="neg_mean_squared_error"
    cross_val = cross_val.ravel()
    print ("CROSS VALIDATION SCORE")
    print ("************************")
    print ("cv-mean :",cross_val.mean()*100)
    print ("cv-std  :",cross_val.std()*100)
    #print ("cv-max  :",cross_val.max()*100)
    #print ("cv-min  :",cross_val.min()*100)
    
    if plot==True:
        plt.figure(figsize=(20,22))
        plt.subplot(211)

        testy = dtesty.reset_index()["Concrete_compressive_strength"]

        ax = testy.plot(label="originals",figsize=(20,9),linewidth=2)
        ax = prediction[0].plot(label = "predictions",figsize=(20,9),linewidth=2)
      #  plt.axhline(testy.mean(),color = "r",linestyle="dashed",label=("original_mean:",testy.mean()))
      #  plt.axhline(prediction[0].mean(),color="b",linestyle = "dashed",label=("prediction_mean:",prediction[0].mean()))
        plt.legend(loc="best")
        plt.title("ORIGINALS VS PREDICTIONS")
        plt.xlabel("index")
        plt.ylabel("values")
        ax.set_facecolor("k")

        plt.subplot(212)

        if of_type == "coef":
            coef = pd.DataFrame(algorithm.coef_.ravel())
            coef["feat"] = dtrainx.columns
            ax1 = sns.barplot(coef["feat"],coef[0],palette="jet_r",
                              linewidth=2,edgecolor="k"*coef["feat"].nunique())
            ax1.set_facecolor("lightgrey")
            ax1.axhline(0,color="k",linewidth=2)
            plt.ylabel("coefficients")
            plt.xlabel("features")
            plt.title('FEATURE IMPORTANCES')

        elif of_type == "feat":
            coef = pd.DataFrame(algorithm.feature_importances_)
            coef["feat"] = dtrainx.columns
            ax2 = sns.barplot(coef["feat"],coef[0],palette="jet_r",
                              linewidth=2,edgecolor="k"*coef["feat"].nunique())
            ax2.set_facecolor("lightgrey")
            ax2.axhline(0,color="k",linewidth=2)
            plt.ylabel("coefficients")
            plt.xlabel("features")
            plt.title('FEATURE IMPORTANCES')

# %% [markdown]
# ### XGBoost Regressor

# %%
import xgboost as xgb
from xgboost.sklearn import XGBRegressor
xgr =XGBRegressor(random_state=2)
#model(xgr,X_train_or,y_train_or,X_test_or,y_test_or,"feat")
model(xgr,X_train,y_train,X_test,y_test,"feat")
#model(xgr,X_train_out,y_train_out,X_test_out,y_test_out,"feat")
#model(xgr,X_train_red,y_train_red,X_test_red,y_test_red,"feat")
#model(xgr,X_train_wc,y_train_wc,X_test_wc,y_test_wc,"feat")
#model(xgr,X_train_wb,y_train_wb,X_test_wb,y_test_wb,"feat")
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              random_state=2, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=None)
# ***************************************************************************
# ROOT MEAN SQUARED ERROR : 4.293225914677778
# ***************************************************************************
# Performance on training data : 99.60602815057365
# Performance on testing data : 93.62626127437285
# ***************************************************************************
# CROSS VALIDATION SCORE
# ************************
# cv-mean : 87.91151609103451
# cv-std  : 6.331470483450176

# %%
xgr_1=XGBRegressor(random_state=2,learning_rate = 0.2,
                max_depth = 2, n_estimators = 800,n_jobs=-1,reg_alpha=0.005,gamma=0.1,subsample=0.7,colsample_bytree=0.9, colsample_bylevel=0.9, colsample_bynode=0.9)
model(xgr_1,X_train,y_train,X_test,y_test,"feat",True)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=0.9,
#              colsample_bynode=0.9, colsample_bytree=0.9, gamma=0.1, gpu_id=None,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.2, max_delta_step=None, max_depth=2,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=800, n_jobs=-1, num_parallel_tree=None,
#              random_state=2, reg_alpha=0.005, reg_lambda=None,
#              scale_pos_weight=None, subsample=0.7, tree_method=None,
#              validate_parameters=None, verbosity=None)
# ***************************************************************************
# ROOT MEAN SQUARED ERROR : 3.4502786463067987
# ***************************************************************************
# Performance on training data : 98.3023947065428
# Performance on testing data : 95.88343371243803
# ***************************************************************************
# CROSS VALIDATION SCORE
# ************************
# cv-mean : 91.58569019135457
# cv-std  : 2.8588588059265083

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
param_grid={'n_estimators' : [500,800,1000],
                                                    'max_depth' : [1,2, 3,5,7,9,10,11,15],
                                                    'learning_rate' :[ 0.0001, 0.001, 0.01, 0.1, 0.15, 0.2, 0.8, 1.0],
                                                     }
# Create a base model
xgbr = XGBRegressor(random_state = 2,reg_alpha=0.005,gamma=0.1,subsample=0.7,colsample_bytree=0.9, colsample_bylevel=0.9, colsample_bynode=0.9)

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = xgbr, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %%
grid_search.fit(X_train, y_train);
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:   48.6s
# [Parallel(n_jobs=-1)]: Done 648 out of 648 | elapsed:   50.8s finished

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.2, 'max_depth': 2, 'n_estimators': 1000}

# %%
best_grid = grid_search.best_estimator_
model(best_grid,X_train,y_train,X_test,y_test,"feat",True)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=0.9,
#              colsample_bynode=0.9, colsample_bytree=0.9, gamma=0.1, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.2, max_delta_step=0, max_depth=2,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=0, num_parallel_tree=1, random_state=2,
#              reg_alpha=0.005, reg_lambda=1, scale_pos_weight=1, subsample=0.7,
#              tree_method='exact', validate_parameters=1, verbosity=None)
# ***************************************************************************
# ROOT MEAN SQUARED ERROR : 3.4521891604676678
# ***************************************************************************
# Performance on training data : 98.50802800350095
# Performance on testing data : 95.8788735383423
# ***************************************************************************
# CROSS VALIDATION SCORE
# ************************
# cv-mean : 91.66990692010944
# cv-std  : 2.67588558574943

# %% [markdown]
# ### Bagging Regressor

# %%
from sklearn.ensemble import BaggingRegressor
regr = BaggingRegressor(base_estimator=xgr_1,
                         n_estimators=400, random_state=2,n_jobs=-1).fit(X_train, y_train)
pred=regr.predict(X_test)
print('Root Mean Squared Error is: ', np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# Root Mean Squared Error is:  3.681606562241377

# %%
regr_1 = BaggingRegressor(base_estimator=best_grid,
                         n_estimators=400, random_state=2,n_jobs=-1).fit(X_train, y_train)
pred=regr_1.predict(X_test)
print('Root Mean Squared Error is: ', np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# Root Mean Squared Error is:  3.6408372479763034

# %% [markdown]
# <hr><hr>
#
# ### Predicting Output

# %%
test_data = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/concrete_data/testing_set_label.csv')
test_data.columns=['Cement',
       'Blast_Furnace_Slag',
       'Fly_Ash',
       'Water',
       'Superplasticizer',
       'Coarse_Aggregate',
       'Fine_Aggregate', 'Age']

test_data['Water_Cement_ratio']=test_data['Water']/test_data['Cement']
#test_data['Water_Binder_ratio']=test_data['Water']/(test_data['Cement']+test_data['Blast_Furnace_Slag']+test_data['Fly_Ash'])

# %%
test_data=test_data[['Superplasticizer', 'Coarse_Aggregate', 'Fine_Aggregate', 'Age',
       'Water_Cement_ratio', 'Blast_Furnace_Slag', 'Fly_Ash']]

# %%
target = regr_1.predict(test_data)
#target = model_nn.predict(sc.transform(test_data))

# %%
res = pd.DataFrame(target) #target is nothing but the final predictions of your model on input features of your new unseen test data
res.index = test_data.index # its important for comparison. Here "test_new" is your new test dataset
res.columns = ["prediction"]
res.to_csv("final_predictions.csv")      # the csv file will be saved locally on the same location where this notebook is located.

# %% [markdown]
# <hr><hr><hr>
#
# ### Other methods that didn't perform well

# %%
### Gradient Boosting Regressor
from sklearn.ensemble import  GradientBoostingRegressor
gbr = GradientBoostingRegressor()
model(gbr,X_train,y_train,X_test,y_test,"feat")
# Out:
# GradientBoostingRegressor()
# ***************************************************************************
# ROOT MEAN SQUARED ERROR : 5.008010927751834
# ***************************************************************************
# Performance on training data : 94.36619580223245
# Performance on testing data : 91.32724040466007
# ***************************************************************************
# CROSS VALIDATION SCORE
# ************************
# cv-mean : 87.65802134745945
# cv-std  : 4.093712673647703

# %%
### Random Forest Regressor
from sklearn.ensemble import  RandomForestRegressor
rf = RandomForestRegressor()
model(rf,X_train,y_train,X_test,y_test,"feat")
# Out:
# RandomForestRegressor()
# ***************************************************************************
# ROOT MEAN SQUARED ERROR : 4.874756726723238
# ***************************************************************************
# Performance on training data : 98.13379852670631
# Performance on testing data : 91.78263331719162
# ***************************************************************************
# CROSS VALIDATION SCORE
# ************************
# cv-mean : 87.04490886514857
# cv-std  : 5.241244488730491

# %%
### Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
model(dtr,X_train,y_train,X_test,y_test,"feat")
# Out:
# DecisionTreeRegressor()
# ***************************************************************************
# ROOT MEAN SQUARED ERROR : 6.515458929793951
# ***************************************************************************
# Performance on training data : 99.6598304897822
# Performance on testing data : 85.32031300477297
# ***************************************************************************
# CROSS VALIDATION SCORE
# ************************
# cv-mean : 81.89116288257556
# cv-std  : 8.13810246840993

# %%
### Extra Trees Regressor
from sklearn.ensemble import ExtraTreesRegressor
etr = ExtraTreesRegressor()
model(etr,X_train,y_train,X_test,y_test,"feat")
# Out:
# ExtraTreesRegressor()
# ***************************************************************************
# ROOT MEAN SQUARED ERROR : 4.524873798292467
# ***************************************************************************
# Performance on training data : 99.6598304897822
# Performance on testing data : 92.91989474138155
# ***************************************************************************
# CROSS VALIDATION SCORE
# ************************
# cv-mean : 87.62836483364899
# cv-std  : 6.1035857159278795

# %%
### AdaBoost Regressor
from sklearn.ensemble import AdaBoostRegressor
adb = AdaBoostRegressor()
model(adb,X_train,y_train,X_test,y_test,"feat")
# Out:
# AdaBoostRegressor()
# ***************************************************************************
# ROOT MEAN SQUARED ERROR : 7.646947685812181
# ***************************************************************************
# Performance on training data : 82.67558462666786
# Performance on testing data : 79.77898223963979
# ***************************************************************************
# CROSS VALIDATION SCORE
# ************************
# cv-mean : 76.0088158127106
# cv-std  : 5.65938764653016

# %%
### Ridge Regression
from sklearn.linear_model import  Ridge
ridge = Ridge()
model(ridge,X_train,y_train,X_test,y_test,"coef")
# Out:
# Ridge()
# ***************************************************************************
# ROOT MEAN SQUARED ERROR : 10.164902780121718
# ***************************************************************************
# Performance on training data : 55.740751796115376
# Performance on testing data : 64.26998233000965
# ***************************************************************************
# CROSS VALIDATION SCORE
# ************************
# cv-mean : 53.026510242147694
# cv-std  : 9.940565116690118

# %%
### Lasso Regression
from sklearn.linear_model import Lasso
ls = Lasso()
model(ls,X_train,y_train,X_test,y_test,"coef")
# Out:
# Lasso()
# ***************************************************************************
# ROOT MEAN SQUARED ERROR : 11.966225929798396
# ***************************************************************************
# Performance on training data : 47.10175077175207
# Performance on testing data : 50.48449997369019
# ***************************************************************************
# CROSS VALIDATION SCORE
# ************************
# cv-mean : 44.47929908774865
# cv-std  : 9.043292174273391

# %%
### Linear Regression
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
model(lr,X_train,y_train,X_test,y_test,"coef")
# Out:
# LinearRegression()
# ***************************************************************************
# ROOT MEAN SQUARED ERROR : 10.143250910613844
# ***************************************************************************
# Performance on training data : 55.76703971754856
# Performance on testing data : 64.42203449733246
# ***************************************************************************
# CROSS VALIDATION SCORE
# ************************
# cv-mean : 53.00933448965844
# cv-std  : 10.042259235138685

# %%
### Neural Network
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# Building ANN As a Regressor
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers.normalization import BatchNormalization
from keras import backend

#Defining Root Mean Square Error As our Metric Function 
def rmse(y_true, y_pred):
    return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# Initialising the ANN
model_nn = Sequential()

# Adding the input layer and the first hidden layer
model_nn.add(Dense(512, activation = 'relu', input_dim = 7))
model_nn.add(BatchNormalization())
# Adding the second hidden layer
model_nn.add(Dense(units = 256, activation = 'relu'))
model_nn.add(BatchNormalization())
# Adding the third hidden layer
model_nn.add(Dense(units = 128, activation = 'relu'))
model_nn.add(BatchNormalization())
model_nn.add(Dense(units = 32, activation = 'relu'))
model_nn.add(BatchNormalization())
# Adding the output layer
model_nn.add(Dense(units = 1))

# Optimize , Compile And Train The Model 
opt =keras.optimizers.Adam(lr=0.0015)
#print(model_nn.summary())
model_nn.compile(optimizer=opt,loss='mean_squared_error',metrics=[rmse])

# %% [markdown]
# history = model_nn.fit(sc.fit_transform(X_train),y_train,epochs = 200 ,batch_size=32,validation_data=(sc.transform(X_test), y_test))

# %%
import tensorflow as tf
checkpoint_filepath ='best.hdf5'# 'C:/Users/admin\/Downloads/Study/Dphi/Datathon 4'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_rmse',
    mode='min',
    save_best_only=True)

# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history=model_nn.fit(sc.fit_transform(X_train),y_train,epochs = 500 ,batch_size=32,validation_data=(sc.transform(X_test), y_test), callbacks=[model_checkpoint_callback])

# The model weights (that are considered the best) are loaded into the model.
model_nn.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/500
# 19/19 [==============================] - 0s 21ms/step - loss: 1446.6202 - rmse: 35.4475 - val_loss: 1573.5015 - val_rmse: 36.2008
# Epoch 2/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1369.7306 - rmse: 35.1712 - val_loss: 1559.9540 - val_rmse: 36.3410
# Epoch 3/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1317.0396 - rmse: 34.8262 - val_loss: 1541.0643 - val_rmse: 36.3253
# Epoch 4/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1271.3938 - rmse: 34.4117 - val_loss: 1522.7079 - val_rmse: 36.4527
# Epoch 5/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1220.1991 - rmse: 33.9259 - val_loss: 1481.5537 - val_rmse: 36.1510
# Epoch 6/500
# 19/19 [==============================] - 0s 8ms/step - loss: 1172.0770 - rmse: 33.3661 - val_loss: 1441.0273 - val_rmse: 35.7041
# Epoch 7/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1128.1516 - rmse: 32.7540 - val_loss: 1370.3181 - val_rmse: 34.7120
# Epoch 8/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1078.2188 - rmse: 32.0492 - val_loss: 1272.0035 - val_rmse: 33.5950
# Epoch 9/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1030.3671 - rmse: 31.2713 - val_loss: 1177.2767 - val_rmse: 32.1657
# Epoch 10/500
# 19/19 [==============================] - 0s 4ms/step - loss: 968.1076 - rmse: 30.4094 - val_loss: 1214.0374 - val_rmse: 32.6993
# Epoch 11/500
# 19/19 [==============================] - 0s 7ms/step - loss: 917.3197 - rmse: 29.4876 - val_loss: 1084.2061 - val_rmse: 30.9328
# Epoch 12/500
# 19/19 [==============================] - 0s 7ms/step - loss: 858.1622 - rmse: 28.4863 - val_loss: 936.0111 - val_rmse: 28.7204
# Epoch 13/500
# 19/19 [==============================] - 0s 7ms/step - loss: 799.6765 - rmse: 27.3830 - val_loss: 860.0771 - val_rmse: 27.4369
# Epoch 14/500
# 19/19 [==============================] - 0s 7ms/step - loss: 728.3726 - rmse: 26.2296 - val_loss: 799.2803 - val_rmse: 26.3710
# Epoch 15/500
# 19/19 [==============================] - 0s 7ms/step - loss: 666.8849 - rmse: 24.9937 - val_loss: 719.7490 - val_rmse: 24.7957
# Epoch 16/500
# 19/19 [==============================] - 0s 7ms/step - loss: 597.8209 - rmse: 23.7008 - val_loss: 686.8588 - val_rmse: 24.1728
# Epoch 17/500
# 19/19 [==============================] - 0s 7ms/step - loss: 535.3170 - rmse: 22.3595 - val_loss: 601.8245 - val_rmse: 22.6004
# Epoch 18/500
# 19/19 [==============================] - 0s 6ms/step - loss: 482.3910 - rmse: 20.9350 - val_loss: 493.1042 - val_rmse: 20.5873
# Epoch 19/500
# 19/19 [==============================] - 0s 7ms/step - loss: 416.9953 - rmse: 19.4724 - val_loss: 439.6320 - val_rmse: 19.3270
# Epoch 20/500
# 19/19 [==============================] - 0s 7ms/step - loss: 363.3685 - rmse: 18.0217 - val_loss: 386.9195 - val_rmse: 18.0556
# Epoch 21/500
# 19/19 [==============================] - 0s 7ms/step - loss: 304.1530 - rmse: 16.4935 - val_loss: 305.8736 - val_rmse: 16.1524
# Epoch 22/500
# 19/19 [==============================] - 0s 6ms/step - loss: 260.2936 - rmse: 15.0502 - val_loss: 272.7345 - val_rmse: 15.0328
# Epoch 23/500
# 19/19 [==============================] - 0s 6ms/step - loss: 218.3994 - rmse: 13.6493 - val_loss: 236.2505 - val_rmse: 13.8264
# Epoch 24/500
# 19/19 [==============================] - 0s 7ms/step - loss: 184.3701 - rmse: 12.2777 - val_loss: 219.9340 - val_rmse: 12.6836
# Epoch 25/500
# 19/19 [==============================] - 0s 6ms/step - loss: 156.8302 - rmse: 11.1519 - val_loss: 177.3291 - val_rmse: 11.1575
# Epoch 26/500
# 19/19 [==============================] - 0s 7ms/step - loss: 124.4696 - rmse: 9.8034 - val_loss: 112.2001 - val_rmse: 8.9936
# Epoch 27/500
# 19/19 [==============================] - 0s 7ms/step - loss: 103.1108 - rmse: 8.7755 - val_loss: 100.0668 - val_rmse: 7.8206
# Epoch 28/500
# 19/19 [==============================] - 0s 7ms/step - loss: 89.7318 - rmse: 7.9641 - val_loss: 74.6323 - val_rmse: 7.0247
# Epoch 29/500
# 19/19 [==============================] - 0s 7ms/step - loss: 76.5032 - rmse: 7.2531 - val_loss: 64.4233 - val_rmse: 6.6030
# Epoch 30/500
# 19/19 [==============================] - 0s 7ms/step - loss: 58.0821 - rmse: 6.3297 - val_loss: 64.5536 - val_rmse: 6.3556
# Epoch 31/500
# 19/19 [==============================] - 0s 7ms/step - loss: 49.5642 - rmse: 5.6693 - val_loss: 52.7036 - val_rmse: 5.4214
# Epoch 32/500
# 19/19 [==============================] - 0s 6ms/step - loss: 50.2789 - rmse: 5.6513 - val_loss: 52.7854 - val_rmse: 5.6038
# Epoch 33/500
# 19/19 [==============================] - 0s 7ms/step - loss: 49.2038 - rmse: 5.5144 - val_loss: 42.7774 - val_rmse: 5.0432
# Epoch 34/500
# 19/19 [==============================] - 0s 5ms/step - loss: 45.7709 - rmse: 5.4163 - val_loss: 48.2867 - val_rmse: 5.2269
# Epoch 35/500
# 19/19 [==============================] - 0s 7ms/step - loss: 44.5539 - rmse: 5.1464 - val_loss: 40.5010 - val_rmse: 4.9114
# Epoch 36/500
# 19/19 [==============================] - 0s 7ms/step - loss: 45.5419 - rmse: 5.1515 - val_loss: 39.1912 - val_rmse: 4.9032
# Epoch 37/500
# 19/19 [==============================] - 0s 5ms/step - loss: 38.5278 - rmse: 4.7934 - val_loss: 48.8397 - val_rmse: 5.5149
# Epoch 38/500
# 19/19 [==============================] - 0s 4ms/step - loss: 37.4268 - rmse: 4.7002 - val_loss: 42.9907 - val_rmse: 5.2479
# Epoch 39/500
# 19/19 [==============================] - 0s 7ms/step - loss: 36.8358 - rmse: 4.6488 - val_loss: 36.0231 - val_rmse: 4.8775
# Epoch 40/500
# 19/19 [==============================] - 0s 6ms/step - loss: 36.9247 - rmse: 4.7399 - val_loss: 33.2566 - val_rmse: 4.5978
# Epoch 41/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30.6528 - rmse: 4.1422 - val_loss: 34.5480 - val_rmse: 4.3608
# Epoch 42/500
# 19/19 [==============================] - 0s 7ms/step - loss: 29.1236 - rmse: 4.1465 - val_loss: 27.8727 - val_rmse: 4.1364
# Epoch 43/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26.2162 - rmse: 3.9184 - val_loss: 24.7105 - val_rmse: 3.7530
# Epoch 44/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30.8575 - rmse: 4.2029 - val_loss: 33.5643 - val_rmse: 4.2827
# Epoch 45/500
# 19/19 [==============================] - 0s 3ms/step - loss: 34.1766 - rmse: 4.4826 - val_loss: 25.7154 - val_rmse: 3.9254
# Epoch 46/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29.1953 - rmse: 4.1626 - val_loss: 25.1852 - val_rmse: 3.9001
# Epoch 47/500
# 19/19 [==============================] - 0s 5ms/step - loss: 36.7094 - rmse: 4.5768 - val_loss: 27.1962 - val_rmse: 3.9777
# Epoch 48/500
# 19/19 [==============================] - 0s 5ms/step - loss: 34.5741 - rmse: 4.5713 - val_loss: 28.5140 - val_rmse: 4.1866
# Epoch 49/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30.7874 - rmse: 4.2242 - val_loss: 28.3389 - val_rmse: 4.1647
# Epoch 50/500
# 19/19 [==============================] - 0s 6ms/step - loss: 37.9403 - rmse: 4.7821 - val_loss: 33.7868 - val_rmse: 4.1865
# Epoch 51/500
# 19/19 [==============================] - 0s 7ms/step - loss: 30.6937 - rmse: 4.2518 - val_loss: 29.2710 - val_rmse: 3.9840
# Epoch 52/500
# 19/19 [==============================] - 0s 4ms/step - loss: 33.7683 - rmse: 4.4174 - val_loss: 28.6830 - val_rmse: 4.1553
# Epoch 53/500
# 19/19 [==============================] - 0s 5ms/step - loss: 33.1197 - rmse: 4.5048 - val_loss: 35.0838 - val_rmse: 4.8362
# Epoch 54/500
# 19/19 [==============================] - 0s 7ms/step - loss: 36.0849 - rmse: 4.5975 - val_loss: 41.7096 - val_rmse: 4.6052
# Epoch 55/500
# 19/19 [==============================] - 0s 5ms/step - loss: 36.5277 - rmse: 4.6426 - val_loss: 26.5236 - val_rmse: 3.9204
# Epoch 56/500
# 19/19 [==============================] - 0s 5ms/step - loss: 28.1214 - rmse: 4.0572 - val_loss: 32.7844 - val_rmse: 4.3633
# Epoch 57/500
# 19/19 [==============================] - 0s 5ms/step - loss: 31.3903 - rmse: 4.3731 - val_loss: 25.4922 - val_rmse: 4.0430
# Epoch 58/500
# 19/19 [==============================] - 0s 5ms/step - loss: 34.7351 - rmse: 4.6571 - val_loss: 26.9900 - val_rmse: 3.9339
# Epoch 59/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.2805 - rmse: 4.0787 - val_loss: 28.8101 - val_rmse: 4.0795
# Epoch 60/500
# 19/19 [==============================] - 0s 5ms/step - loss: 31.5297 - rmse: 4.1920 - val_loss: 23.9737 - val_rmse: 3.8660
# Epoch 61/500
# 19/19 [==============================] - 0s 4ms/step - loss: 37.1469 - rmse: 4.6771 - val_loss: 31.4688 - val_rmse: 4.1101
# Epoch 62/500
# 19/19 [==============================] - 0s 6ms/step - loss: 35.9648 - rmse: 4.5806 - val_loss: 37.8023 - val_rmse: 4.4147
# Epoch 63/500
# 19/19 [==============================] - 0s 6ms/step - loss: 33.6551 - rmse: 4.4493 - val_loss: 27.9293 - val_rmse: 4.2114
# Epoch 64/500
# 19/19 [==============================] - 0s 6ms/step - loss: 31.7637 - rmse: 4.4282 - val_loss: 23.5315 - val_rmse: 3.7670
# Epoch 65/500
# 19/19 [==============================] - 0s 3ms/step - loss: 31.3055 - rmse: 4.2380 - val_loss: 32.2325 - val_rmse: 4.1044
# Epoch 66/500
# 19/19 [==============================] - 0s 8ms/step - loss: 30.1216 - rmse: 4.1334 - val_loss: 21.7941 - val_rmse: 3.4895
# Epoch 67/500
# 19/19 [==============================] - 0s 5ms/step - loss: 33.3503 - rmse: 4.4129 - val_loss: 28.7786 - val_rmse: 4.0821
# Epoch 68/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.8128 - rmse: 4.2136 - val_loss: 26.0361 - val_rmse: 3.8279
# Epoch 69/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30.2781 - rmse: 4.1839 - val_loss: 30.5427 - val_rmse: 3.9732
# Epoch 70/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.9131 - rmse: 3.8310 - val_loss: 22.5719 - val_rmse: 3.5775
# Epoch 71/500
# 19/19 [==============================] - 0s 5ms/step - loss: 32.1338 - rmse: 4.3343 - val_loss: 27.6751 - val_rmse: 3.9077
# Epoch 72/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.0093 - rmse: 4.1208 - val_loss: 24.1580 - val_rmse: 3.6607
# Epoch 73/500
# 19/19 [==============================] - 0s 5ms/step - loss: 28.0356 - rmse: 4.0919 - val_loss: 25.9814 - val_rmse: 3.8139
# Epoch 74/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29.1647 - rmse: 4.1019 - val_loss: 22.8911 - val_rmse: 3.5514
# Epoch 75/500
# 19/19 [==============================] - 0s 6ms/step - loss: 31.9254 - rmse: 4.3637 - val_loss: 23.7649 - val_rmse: 3.6686
# Epoch 76/500
# 19/19 [==============================] - 0s 6ms/step - loss: 24.3468 - rmse: 3.8051 - val_loss: 20.8790 - val_rmse: 3.4527
# Epoch 77/500
# 19/19 [==============================] - 0s 4ms/step - loss: 31.6723 - rmse: 4.3554 - val_loss: 20.4157 - val_rmse: 3.4597
# Epoch 78/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.8278 - rmse: 4.1411 - val_loss: 27.5423 - val_rmse: 3.8542
# Epoch 79/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29.9909 - rmse: 4.1802 - val_loss: 24.1150 - val_rmse: 3.8369
# Epoch 80/500
# 19/19 [==============================] - 0s 5ms/step - loss: 31.6987 - rmse: 4.3751 - val_loss: 28.3308 - val_rmse: 4.2191
# Epoch 81/500
# 19/19 [==============================] - 0s 7ms/step - loss: 44.5974 - rmse: 5.0645 - val_loss: 30.1762 - val_rmse: 4.2787
# Epoch 82/500
# 19/19 [==============================] - 0s 6ms/step - loss: 34.7945 - rmse: 4.5948 - val_loss: 28.7625 - val_rmse: 4.2959
# Epoch 83/500
# 19/19 [==============================] - 0s 5ms/step - loss: 31.0541 - rmse: 4.3388 - val_loss: 24.2709 - val_rmse: 3.9211
# Epoch 84/500
# 19/19 [==============================] - 0s 5ms/step - loss: 31.5214 - rmse: 4.3785 - val_loss: 21.8256 - val_rmse: 3.5623
# Epoch 85/500
# 19/19 [==============================] - 0s 6ms/step - loss: 34.2684 - rmse: 4.2772 - val_loss: 27.1734 - val_rmse: 4.0418
# Epoch 86/500
# 19/19 [==============================] - 0s 5ms/step - loss: 36.1394 - rmse: 4.7424 - val_loss: 31.8613 - val_rmse: 4.2342
# Epoch 87/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30.2279 - rmse: 4.1639 - val_loss: 31.6563 - val_rmse: 4.1520
# Epoch 88/500
# 19/19 [==============================] - 0s 6ms/step - loss: 36.6022 - rmse: 4.7210 - val_loss: 25.3993 - val_rmse: 3.7220
# Epoch 89/500
# 19/19 [==============================] - 0s 5ms/step - loss: 28.5833 - rmse: 3.9611 - val_loss: 23.9355 - val_rmse: 3.6715
# Epoch 90/500
# 19/19 [==============================] - 0s 6ms/step - loss: 32.1656 - rmse: 4.3556 - val_loss: 27.5930 - val_rmse: 3.9823
# Epoch 91/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30.7182 - rmse: 4.2035 - val_loss: 25.9377 - val_rmse: 3.9598
# Epoch 92/500
# 19/19 [==============================] - 0s 6ms/step - loss: 34.0893 - rmse: 4.4381 - val_loss: 28.9731 - val_rmse: 4.0129
# Epoch 93/500
# 19/19 [==============================] - 0s 5ms/step - loss: 32.0589 - rmse: 4.3789 - val_loss: 25.8114 - val_rmse: 3.8166
# Epoch 94/500
# 19/19 [==============================] - 0s 5ms/step - loss: 27.2507 - rmse: 4.0321 - val_loss: 28.6689 - val_rmse: 3.9694
# Epoch 95/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.8391 - rmse: 3.9517 - val_loss: 23.6670 - val_rmse: 3.6802
# Epoch 96/500
# 19/19 [==============================] - 0s 7ms/step - loss: 25.2027 - rmse: 3.9622 - val_loss: 18.6880 - val_rmse: 3.2378
# Epoch 97/500
# 19/19 [==============================] - 0s 6ms/step - loss: 27.7111 - rmse: 3.9483 - val_loss: 19.4765 - val_rmse: 3.3702
# Epoch 98/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.6595 - rmse: 4.2053 - val_loss: 24.3376 - val_rmse: 3.7291
# Epoch 99/500
# 19/19 [==============================] - 0s 6ms/step - loss: 25.7955 - rmse: 3.8814 - val_loss: 19.2537 - val_rmse: 3.3158
# Epoch 100/500
# 19/19 [==============================] - 0s 5ms/step - loss: 33.5992 - rmse: 4.5373 - val_loss: 26.3655 - val_rmse: 3.7733
# Epoch 101/500
# 19/19 [==============================] - 0s 6ms/step - loss: 31.5755 - rmse: 4.4797 - val_loss: 22.8014 - val_rmse: 3.5093
# Epoch 102/500
# 19/19 [==============================] - 0s 5ms/step - loss: 51.2551 - rmse: 5.5726 - val_loss: 38.0159 - val_rmse: 4.6222
# Epoch 103/500
# 19/19 [==============================] - 0s 6ms/step - loss: 36.4046 - rmse: 4.7669 - val_loss: 42.5716 - val_rmse: 4.8445
# Epoch 104/500
# 19/19 [==============================] - 0s 5ms/step - loss: 28.8831 - rmse: 4.1940 - val_loss: 27.1790 - val_rmse: 3.7048
# Epoch 105/500
# 19/19 [==============================] - 0s 6ms/step - loss: 25.3796 - rmse: 3.8811 - val_loss: 28.3324 - val_rmse: 3.8290
# Epoch 106/500
# 19/19 [==============================] - 0s 7ms/step - loss: 32.6351 - rmse: 4.4258 - val_loss: 22.4280 - val_rmse: 3.4863
# Epoch 107/500
# 19/19 [==============================] - 0s 5ms/step - loss: 31.0225 - rmse: 4.1408 - val_loss: 22.7307 - val_rmse: 3.4515
# Epoch 108/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.8970 - rmse: 4.1283 - val_loss: 22.3122 - val_rmse: 3.3948
# Epoch 109/500
# 19/19 [==============================] - 0s 6ms/step - loss: 34.2497 - rmse: 4.2569 - val_loss: 25.6933 - val_rmse: 3.7316
# Epoch 110/500
# 19/19 [==============================] - 0s 6ms/step - loss: 33.2240 - rmse: 4.5224 - val_loss: 21.6139 - val_rmse: 3.5681
# Epoch 111/500
# 19/19 [==============================] - 0s 4ms/step - loss: 32.2553 - rmse: 4.4663 - val_loss: 26.6890 - val_rmse: 3.8555
# Epoch 112/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.2412 - rmse: 3.7995 - val_loss: 21.6153 - val_rmse: 3.5337
# Epoch 113/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.1470 - rmse: 3.6847 - val_loss: 22.7819 - val_rmse: 3.5443
# Epoch 114/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.0942 - rmse: 3.7017 - val_loss: 21.9088 - val_rmse: 3.4843
# Epoch 115/500
# 19/19 [==============================] - 0s 6ms/step - loss: 22.3042 - rmse: 3.6653 - val_loss: 20.1702 - val_rmse: 3.4602
# Epoch 116/500
# 19/19 [==============================] - 0s 5ms/step - loss: 36.2653 - rmse: 4.5496 - val_loss: 22.1890 - val_rmse: 3.6727
# Epoch 117/500
# 19/19 [==============================] - 0s 5ms/step - loss: 28.0642 - rmse: 3.9624 - val_loss: 23.5097 - val_rmse: 3.5882
# Epoch 118/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.4707 - rmse: 4.1670 - val_loss: 22.1512 - val_rmse: 3.5364
# Epoch 119/500
# 19/19 [==============================] - 0s 6ms/step - loss: 31.3751 - rmse: 4.4706 - val_loss: 29.0804 - val_rmse: 3.7906
# Epoch 120/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29.1203 - rmse: 4.1754 - val_loss: 24.7153 - val_rmse: 3.7989
# Epoch 121/500
# 19/19 [==============================] - 0s 6ms/step - loss: 23.8723 - rmse: 3.7500 - val_loss: 24.2184 - val_rmse: 3.6421
# Epoch 122/500
# 19/19 [==============================] - 0s 6ms/step - loss: 32.7832 - rmse: 4.4366 - val_loss: 24.3747 - val_rmse: 3.5806
# Epoch 123/500
# 19/19 [==============================] - 0s 4ms/step - loss: 32.5973 - rmse: 4.4880 - val_loss: 29.6244 - val_rmse: 3.9268
# Epoch 124/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.3374 - rmse: 3.9488 - val_loss: 27.0082 - val_rmse: 3.9457
# Epoch 125/500
# 19/19 [==============================] - 0s 4ms/step - loss: 23.9604 - rmse: 3.7007 - val_loss: 27.2908 - val_rmse: 3.7855
# Epoch 126/500
# 19/19 [==============================] - 0s 4ms/step - loss: 30.0931 - rmse: 4.2050 - val_loss: 25.9478 - val_rmse: 3.7649
# Epoch 127/500
# 19/19 [==============================] - 0s 4ms/step - loss: 27.1273 - rmse: 3.9528 - val_loss: 28.1620 - val_rmse: 3.9257
# Epoch 128/500
# 19/19 [==============================] - 0s 5ms/step - loss: 33.8996 - rmse: 4.5077 - val_loss: 24.6030 - val_rmse: 3.8043
# Epoch 129/500
# 19/19 [==============================] - 0s 5ms/step - loss: 33.3353 - rmse: 4.5029 - val_loss: 26.3645 - val_rmse: 3.9886
# Epoch 130/500
# 19/19 [==============================] - 0s 3ms/step - loss: 31.2183 - rmse: 4.2919 - val_loss: 24.0996 - val_rmse: 3.8286
# Epoch 131/500
# 19/19 [==============================] - 0s 4ms/step - loss: 35.4708 - rmse: 4.6868 - val_loss: 22.3221 - val_rmse: 3.5970
# Epoch 132/500
# 19/19 [==============================] - 0s 4ms/step - loss: 25.8069 - rmse: 3.8207 - val_loss: 20.9712 - val_rmse: 3.4074
# Epoch 133/500
# 19/19 [==============================] - 0s 3ms/step - loss: 23.1250 - rmse: 3.7639 - val_loss: 22.1896 - val_rmse: 3.5427
# Epoch 134/500
# 19/19 [==============================] - 0s 7ms/step - loss: 23.4673 - rmse: 3.6943 - val_loss: 18.0744 - val_rmse: 3.1948
# Epoch 135/500
# 19/19 [==============================] - 0s 4ms/step - loss: 23.1063 - rmse: 3.6904 - val_loss: 23.3118 - val_rmse: 3.5610
# Epoch 136/500
# 19/19 [==============================] - 0s 4ms/step - loss: 29.5602 - rmse: 3.9116 - val_loss: 20.0992 - val_rmse: 3.4024
# Epoch 137/500
# 19/19 [==============================] - 0s 5ms/step - loss: 27.4328 - rmse: 4.0609 - val_loss: 20.5244 - val_rmse: 3.4578
# Epoch 138/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.5111 - rmse: 3.8582 - val_loss: 25.1606 - val_rmse: 3.8808
# Epoch 139/500
# 19/19 [==============================] - 0s 4ms/step - loss: 47.8552 - rmse: 5.0963 - val_loss: 33.1722 - val_rmse: 4.4230
# Epoch 140/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.9648 - rmse: 4.3236 - val_loss: 33.9798 - val_rmse: 4.4294
# Epoch 141/500
# 19/19 [==============================] - 0s 4ms/step - loss: 34.0227 - rmse: 4.5401 - val_loss: 28.0373 - val_rmse: 3.9320
# Epoch 142/500
# 19/19 [==============================] - 0s 5ms/step - loss: 22.5591 - rmse: 3.6164 - val_loss: 26.5919 - val_rmse: 3.8578
# Epoch 143/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30.5193 - rmse: 4.2070 - val_loss: 23.4422 - val_rmse: 3.6046
# Epoch 144/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.8224 - rmse: 3.7489 - val_loss: 21.5303 - val_rmse: 3.4592
# Epoch 145/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.2627 - rmse: 3.7186 - val_loss: 22.4780 - val_rmse: 3.5715
# Epoch 146/500
# 19/19 [==============================] - 0s 5ms/step - loss: 20.6480 - rmse: 3.3832 - val_loss: 22.3505 - val_rmse: 3.4587
# Epoch 147/500
# 19/19 [==============================] - 0s 4ms/step - loss: 27.7318 - rmse: 4.0448 - val_loss: 20.4912 - val_rmse: 3.3289
# Epoch 148/500
# 19/19 [==============================] - 0s 5ms/step - loss: 31.4394 - rmse: 4.3869 - val_loss: 23.1151 - val_rmse: 3.4838
# Epoch 149/500
# 19/19 [==============================] - 0s 4ms/step - loss: 27.9996 - rmse: 4.0882 - val_loss: 21.0952 - val_rmse: 3.4598
# Epoch 150/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.4430 - rmse: 4.2127 - val_loss: 22.1176 - val_rmse: 3.5171
# Epoch 151/500
# 19/19 [==============================] - 0s 4ms/step - loss: 31.0971 - rmse: 4.2083 - val_loss: 27.8550 - val_rmse: 3.7959
# Epoch 152/500
# 19/19 [==============================] - 0s 3ms/step - loss: 25.7919 - rmse: 3.9201 - val_loss: 20.7928 - val_rmse: 3.3907
# Epoch 153/500
# 19/19 [==============================] - 0s 3ms/step - loss: 28.9608 - rmse: 4.2695 - val_loss: 21.2500 - val_rmse: 3.3785
# Epoch 154/500
# 19/19 [==============================] - 0s 4ms/step - loss: 26.0339 - rmse: 3.8949 - val_loss: 20.1835 - val_rmse: 3.4298
# Epoch 155/500
# 19/19 [==============================] - 0s 5ms/step - loss: 20.3894 - rmse: 3.5389 - val_loss: 20.6529 - val_rmse: 3.3931
# Epoch 156/500
# 19/19 [==============================] - 0s 6ms/step - loss: 31.8765 - rmse: 4.3404 - val_loss: 23.3934 - val_rmse: 3.5827
# Epoch 157/500
# 19/19 [==============================] - 0s 5ms/step - loss: 31.2815 - rmse: 4.3635 - val_loss: 20.6631 - val_rmse: 3.3194
# Epoch 158/500
# 19/19 [==============================] - 0s 4ms/step - loss: 30.6874 - rmse: 4.3116 - val_loss: 21.4930 - val_rmse: 3.4534
# Epoch 159/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.2571 - rmse: 4.1749 - val_loss: 33.9174 - val_rmse: 4.3604
# Epoch 160/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.6021 - rmse: 3.5544 - val_loss: 24.8851 - val_rmse: 3.6786
# Epoch 161/500
# 19/19 [==============================] - 0s 5ms/step - loss: 27.7813 - rmse: 4.0409 - val_loss: 22.0723 - val_rmse: 3.4644
# Epoch 162/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.5494 - rmse: 3.8914 - val_loss: 19.1837 - val_rmse: 3.2057
# Epoch 163/500
# 19/19 [==============================] - 0s 4ms/step - loss: 23.2301 - rmse: 3.7645 - val_loss: 20.9911 - val_rmse: 3.4000
# Epoch 164/500
# 19/19 [==============================] - 0s 5ms/step - loss: 33.8040 - rmse: 4.3400 - val_loss: 25.5219 - val_rmse: 3.7966
# Epoch 165/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.1926 - rmse: 4.2219 - val_loss: 20.3559 - val_rmse: 3.3331
# Epoch 166/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.6015 - rmse: 3.9001 - val_loss: 22.5466 - val_rmse: 3.4426
# Epoch 167/500
# 19/19 [==============================] - 0s 4ms/step - loss: 21.3419 - rmse: 3.6077 - val_loss: 18.8415 - val_rmse: 3.2752
# Epoch 168/500
# 19/19 [==============================] - 0s 7ms/step - loss: 20.1204 - rmse: 3.3546 - val_loss: 19.3766 - val_rmse: 3.1935
# Epoch 169/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.7183 - rmse: 4.0020 - val_loss: 20.9406 - val_rmse: 3.3828
# Epoch 170/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.4797 - rmse: 3.8839 - val_loss: 24.4691 - val_rmse: 3.5815
# Epoch 171/500
# 19/19 [==============================] - 0s 4ms/step - loss: 25.2253 - rmse: 3.7780 - val_loss: 28.9022 - val_rmse: 3.9295
# Epoch 172/500
# 19/19 [==============================] - 0s 3ms/step - loss: 27.4049 - rmse: 3.9450 - val_loss: 22.2160 - val_rmse: 3.6296
# Epoch 173/500
# 19/19 [==============================] - 0s 3ms/step - loss: 25.7270 - rmse: 4.0075 - val_loss: 30.6995 - val_rmse: 4.0280
# Epoch 174/500
# 19/19 [==============================] - 0s 3ms/step - loss: 27.0929 - rmse: 3.9643 - val_loss: 25.5654 - val_rmse: 3.7401
# Epoch 175/500
# 19/19 [==============================] - 0s 3ms/step - loss: 19.0053 - rmse: 3.2454 - val_loss: 24.4630 - val_rmse: 3.6098
# Epoch 176/500
# 19/19 [==============================] - 0s 3ms/step - loss: 26.0200 - rmse: 3.9972 - val_loss: 22.6857 - val_rmse: 3.5497
# Epoch 177/500
# 19/19 [==============================] - 0s 3ms/step - loss: 28.7441 - rmse: 4.0117 - val_loss: 27.9489 - val_rmse: 3.8842
# Epoch 178/500
# 19/19 [==============================] - 0s 3ms/step - loss: 22.8852 - rmse: 3.6540 - val_loss: 23.4815 - val_rmse: 3.6415
# Epoch 179/500
# 19/19 [==============================] - 0s 4ms/step - loss: 24.5240 - rmse: 3.8535 - val_loss: 24.6912 - val_rmse: 3.6331
# Epoch 180/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.6611 - rmse: 3.8687 - val_loss: 26.1124 - val_rmse: 3.8394
# Epoch 181/500
# 19/19 [==============================] - 0s 5ms/step - loss: 19.9245 - rmse: 3.4790 - val_loss: 21.5354 - val_rmse: 3.4250
# Epoch 182/500
# 19/19 [==============================] - 0s 6ms/step - loss: 27.7749 - rmse: 3.9440 - val_loss: 28.4228 - val_rmse: 3.9988
# Epoch 183/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.0136 - rmse: 4.0038 - val_loss: 23.0982 - val_rmse: 3.6889
# Epoch 184/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.2109 - rmse: 3.7511 - val_loss: 22.5633 - val_rmse: 3.5346
# Epoch 185/500
# 19/19 [==============================] - 0s 4ms/step - loss: 34.2513 - rmse: 4.5035 - val_loss: 27.2441 - val_rmse: 4.0326
# Epoch 186/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.9212 - rmse: 3.6183 - val_loss: 26.3612 - val_rmse: 3.8187
# Epoch 187/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.1325 - rmse: 4.0358 - val_loss: 25.9279 - val_rmse: 3.8178
# Epoch 188/500
# 19/19 [==============================] - 0s 4ms/step - loss: 21.0531 - rmse: 3.5227 - val_loss: 22.1859 - val_rmse: 3.4222
# Epoch 189/500
# 19/19 [==============================] - 0s 4ms/step - loss: 32.5532 - rmse: 4.4970 - val_loss: 23.3627 - val_rmse: 3.5762
# Epoch 190/500
# 19/19 [==============================] - 0s 4ms/step - loss: 24.4747 - rmse: 3.8050 - val_loss: 30.7230 - val_rmse: 3.9837
# Epoch 191/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.0390 - rmse: 4.0132 - val_loss: 26.2496 - val_rmse: 3.6398
# Epoch 192/500
# 19/19 [==============================] - 0s 5ms/step - loss: 28.4670 - rmse: 4.0816 - val_loss: 21.5547 - val_rmse: 3.3666
# Epoch 193/500
# 19/19 [==============================] - 0s 4ms/step - loss: 30.2337 - rmse: 4.1792 - val_loss: 22.1769 - val_rmse: 3.4102
# Epoch 194/500
# 19/19 [==============================] - 0s 6ms/step - loss: 19.6009 - rmse: 3.4420 - val_loss: 19.4749 - val_rmse: 3.1599
# Epoch 195/500
# 19/19 [==============================] - 0s 5ms/step - loss: 22.9540 - rmse: 3.6603 - val_loss: 19.6299 - val_rmse: 3.2245
# Epoch 196/500
# 19/19 [==============================] - 0s 5ms/step - loss: 20.2812 - rmse: 3.4763 - val_loss: 19.2457 - val_rmse: 3.1129
# Epoch 197/500
# 19/19 [==============================] - 0s 4ms/step - loss: 25.9223 - rmse: 3.9257 - val_loss: 19.5285 - val_rmse: 3.2061
# Epoch 198/500
# 19/19 [==============================] - 0s 4ms/step - loss: 23.1694 - rmse: 3.6725 - val_loss: 21.2247 - val_rmse: 3.4067
# Epoch 199/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.8554 - rmse: 4.0219 - val_loss: 20.9633 - val_rmse: 3.3257
# Epoch 200/500
# 19/19 [==============================] - 0s 4ms/step - loss: 25.6153 - rmse: 3.8387 - val_loss: 17.9797 - val_rmse: 3.1839
# Epoch 201/500
# 19/19 [==============================] - 0s 5ms/step - loss: 33.9864 - rmse: 4.4378 - val_loss: 22.9955 - val_rmse: 3.4366
# Epoch 202/500
# 19/19 [==============================] - 0s 6ms/step - loss: 22.4751 - rmse: 3.7014 - val_loss: 19.5797 - val_rmse: 3.3162
# Epoch 203/500
# 19/19 [==============================] - 0s 5ms/step - loss: 27.7304 - rmse: 4.0595 - val_loss: 19.0563 - val_rmse: 3.2143
# Epoch 204/500
# 19/19 [==============================] - 0s 5ms/step - loss: 28.0401 - rmse: 4.2071 - val_loss: 18.8624 - val_rmse: 3.1754
# Epoch 205/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26.2596 - rmse: 3.9869 - val_loss: 19.6922 - val_rmse: 3.2916
# Epoch 206/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30.0914 - rmse: 4.2173 - val_loss: 19.2473 - val_rmse: 3.2276
# Epoch 207/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.6008 - rmse: 3.8727 - val_loss: 17.7140 - val_rmse: 3.1173
# Epoch 208/500
# 19/19 [==============================] - 0s 5ms/step - loss: 19.1429 - rmse: 3.4507 - val_loss: 23.1937 - val_rmse: 3.5838
# Epoch 209/500
# 19/19 [==============================] - 0s 5ms/step - loss: 27.7497 - rmse: 4.0174 - val_loss: 18.8041 - val_rmse: 3.2215
# Epoch 210/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.2969 - rmse: 3.7284 - val_loss: 20.4213 - val_rmse: 3.2908
# Epoch 211/500
# 19/19 [==============================] - 0s 5ms/step - loss: 27.5468 - rmse: 3.9285 - val_loss: 20.1720 - val_rmse: 3.3572
# Epoch 212/500
# 19/19 [==============================] - 0s 6ms/step - loss: 34.4366 - rmse: 4.3223 - val_loss: 46.3658 - val_rmse: 4.7447
# Epoch 213/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.3098 - rmse: 4.0595 - val_loss: 33.9768 - val_rmse: 4.6112
# Epoch 214/500
# 19/19 [==============================] - 0s 5ms/step - loss: 31.1381 - rmse: 4.2004 - val_loss: 26.0553 - val_rmse: 3.6727
# Epoch 215/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.1938 - rmse: 3.8728 - val_loss: 23.4810 - val_rmse: 3.5588
# Epoch 216/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.0829 - rmse: 3.6662 - val_loss: 24.5319 - val_rmse: 3.5479
# Epoch 217/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.2660 - rmse: 3.7866 - val_loss: 19.4174 - val_rmse: 3.2562
# Epoch 218/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29.1893 - rmse: 4.1406 - val_loss: 19.3521 - val_rmse: 3.3546
# Epoch 219/500
# 19/19 [==============================] - 0s 6ms/step - loss: 28.8167 - rmse: 4.0485 - val_loss: 23.5668 - val_rmse: 3.5571
# Epoch 220/500
# 19/19 [==============================] - 0s 6ms/step - loss: 24.2525 - rmse: 3.7664 - val_loss: 20.3378 - val_rmse: 3.3035
# Epoch 221/500
# 19/19 [==============================] - 0s 6ms/step - loss: 19.6865 - rmse: 3.4030 - val_loss: 19.1358 - val_rmse: 3.2284
# Epoch 222/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29.1978 - rmse: 4.2188 - val_loss: 21.1050 - val_rmse: 3.4084
# Epoch 223/500
# 19/19 [==============================] - 0s 6ms/step - loss: 31.2776 - rmse: 4.3226 - val_loss: 24.6828 - val_rmse: 3.6541
# Epoch 224/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.9654 - rmse: 3.8458 - val_loss: 19.7211 - val_rmse: 3.4101
# Epoch 225/500
# 19/19 [==============================] - 0s 8ms/step - loss: 25.5452 - rmse: 3.9243 - val_loss: 17.7341 - val_rmse: 3.1046
# Epoch 226/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29.3602 - rmse: 4.2190 - val_loss: 25.7218 - val_rmse: 3.7772
# Epoch 227/500
# 19/19 [==============================] - 0s 6ms/step - loss: 21.9478 - rmse: 3.6476 - val_loss: 18.7912 - val_rmse: 3.1021
# Epoch 228/500
# 19/19 [==============================] - 0s 7ms/step - loss: 27.5387 - rmse: 4.1037 - val_loss: 21.3883 - val_rmse: 3.4540
# Epoch 229/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.0578 - rmse: 3.9867 - val_loss: 19.1459 - val_rmse: 3.3235
# Epoch 230/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.6749 - rmse: 3.5118 - val_loss: 24.4233 - val_rmse: 3.6451
# Epoch 231/500
# 19/19 [==============================] - 0s 6ms/step - loss: 25.7335 - rmse: 3.8650 - val_loss: 20.5610 - val_rmse: 3.3771
# Epoch 232/500
# 19/19 [==============================] - 0s 6ms/step - loss: 23.7666 - rmse: 3.7379 - val_loss: 19.8239 - val_rmse: 3.1573
# Epoch 233/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.9552 - rmse: 3.6348 - val_loss: 20.4032 - val_rmse: 3.3655
# Epoch 234/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.5132 - rmse: 3.5401 - val_loss: 26.2623 - val_rmse: 3.6932
# Epoch 235/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.7255 - rmse: 3.7541 - val_loss: 19.7169 - val_rmse: 3.1599
# Epoch 236/500
# 19/19 [==============================] - 0s 6ms/step - loss: 22.2957 - rmse: 3.6913 - val_loss: 19.9670 - val_rmse: 3.4364
# Epoch 237/500
# 19/19 [==============================] - 0s 6ms/step - loss: 36.0652 - rmse: 4.6729 - val_loss: 31.5460 - val_rmse: 4.4091
# Epoch 238/500
# 19/19 [==============================] - 0s 5ms/step - loss: 32.1334 - rmse: 4.3010 - val_loss: 26.4874 - val_rmse: 3.9426
# Epoch 239/500
# 19/19 [==============================] - 0s 5ms/step - loss: 31.2969 - rmse: 4.3075 - val_loss: 39.8481 - val_rmse: 5.0124
# Epoch 240/500
# 19/19 [==============================] - 0s 10ms/step - loss: 27.1053 - rmse: 3.9782 - val_loss: 26.7740 - val_rmse: 4.0522
# Epoch 241/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.2598 - rmse: 3.9197 - val_loss: 25.0589 - val_rmse: 3.8682
# Epoch 242/500
# 19/19 [==============================] - 0s 5ms/step - loss: 34.9754 - rmse: 4.5590 - val_loss: 28.0816 - val_rmse: 4.2216
# Epoch 243/500
# 19/19 [==============================] - 0s 4ms/step - loss: 26.0982 - rmse: 3.8315 - val_loss: 25.0246 - val_rmse: 3.9726
# Epoch 244/500
# 19/19 [==============================] - 0s 7ms/step - loss: 30.8060 - rmse: 4.3303 - val_loss: 25.4307 - val_rmse: 3.9329
# Epoch 245/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.6128 - rmse: 3.8410 - val_loss: 23.9111 - val_rmse: 3.7434
# Epoch 246/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.1314 - rmse: 3.5151 - val_loss: 22.4331 - val_rmse: 3.6327
# Epoch 247/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.6197 - rmse: 3.6962 - val_loss: 22.7994 - val_rmse: 3.4648
# Epoch 248/500
# 19/19 [==============================] - 0s 8ms/step - loss: 29.1619 - rmse: 4.0635 - val_loss: 27.0618 - val_rmse: 3.6542
# Epoch 249/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30.4666 - rmse: 4.1964 - val_loss: 29.5007 - val_rmse: 4.0867
# Epoch 250/500
# 19/19 [==============================] - 0s 6ms/step - loss: 35.9473 - rmse: 4.7012 - val_loss: 21.3054 - val_rmse: 3.4022
# Epoch 251/500
# 19/19 [==============================] - 0s 4ms/step - loss: 24.8216 - rmse: 3.8133 - val_loss: 23.1628 - val_rmse: 3.5486
# Epoch 252/500
# 19/19 [==============================] - 0s 6ms/step - loss: 23.8155 - rmse: 3.7423 - val_loss: 21.1329 - val_rmse: 3.4268
# Epoch 253/500
# 19/19 [==============================] - 0s 6ms/step - loss: 20.3002 - rmse: 3.4381 - val_loss: 19.8393 - val_rmse: 3.2503
# Epoch 254/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30.4721 - rmse: 4.2506 - val_loss: 18.7476 - val_rmse: 3.2144
# Epoch 255/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.8822 - rmse: 3.7597 - val_loss: 20.5721 - val_rmse: 3.3403
# Epoch 256/500
# 19/19 [==============================] - 0s 7ms/step - loss: 28.6193 - rmse: 4.0174 - val_loss: 21.3679 - val_rmse: 3.4325
# Epoch 257/500
# 19/19 [==============================] - 0s 6ms/step - loss: 24.0054 - rmse: 3.6671 - val_loss: 23.6434 - val_rmse: 3.6291
# Epoch 258/500
# 19/19 [==============================] - 0s 6ms/step - loss: 25.4073 - rmse: 3.8711 - val_loss: 23.7334 - val_rmse: 3.5278
# Epoch 259/500
# 19/19 [==============================] - 0s 5ms/step - loss: 27.4890 - rmse: 3.9167 - val_loss: 28.9098 - val_rmse: 3.8779
# Epoch 260/500
# 19/19 [==============================] - 0s 7ms/step - loss: 24.4691 - rmse: 3.7584 - val_loss: 24.4346 - val_rmse: 3.5878
# Epoch 261/500
# 19/19 [==============================] - 0s 5ms/step - loss: 27.0136 - rmse: 3.9816 - val_loss: 24.5230 - val_rmse: 3.6323
# Epoch 262/500
# 19/19 [==============================] - 0s 5ms/step - loss: 28.7022 - rmse: 3.9645 - val_loss: 21.2529 - val_rmse: 3.2588
# Epoch 263/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.7865 - rmse: 4.2337 - val_loss: 22.2664 - val_rmse: 3.6026
# Epoch 264/500
# 19/19 [==============================] - 0s 6ms/step - loss: 19.9442 - rmse: 3.4906 - val_loss: 20.8768 - val_rmse: 3.3886
# Epoch 265/500
# 19/19 [==============================] - 0s 6ms/step - loss: 28.1956 - rmse: 4.0519 - val_loss: 24.0980 - val_rmse: 3.5075
# Epoch 266/500
# 19/19 [==============================] - 0s 4ms/step - loss: 25.6240 - rmse: 3.9449 - val_loss: 24.2616 - val_rmse: 3.6626
# Epoch 267/500
# 19/19 [==============================] - 0s 4ms/step - loss: 34.1563 - rmse: 4.5263 - val_loss: 27.2567 - val_rmse: 3.9442
# Epoch 268/500
# 19/19 [==============================] - 0s 6ms/step - loss: 27.4467 - rmse: 4.0529 - val_loss: 22.2856 - val_rmse: 3.4576
# Epoch 269/500
# 19/19 [==============================] - 0s 6ms/step - loss: 20.3150 - rmse: 3.4443 - val_loss: 23.3119 - val_rmse: 3.6186
# Epoch 270/500
# 19/19 [==============================] - 0s 6ms/step - loss: 21.6819 - rmse: 3.6588 - val_loss: 21.9506 - val_rmse: 3.3851
# Epoch 271/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.4103 - rmse: 3.6438 - val_loss: 23.9922 - val_rmse: 3.6471
# Epoch 272/500
# 19/19 [==============================] - 0s 6ms/step - loss: 23.7133 - rmse: 3.7679 - val_loss: 23.4795 - val_rmse: 3.6314
# Epoch 273/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.8813 - rmse: 3.6800 - val_loss: 21.3965 - val_rmse: 3.4227
# Epoch 274/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.3317 - rmse: 3.8516 - val_loss: 21.9137 - val_rmse: 3.4255
# Epoch 275/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.4360 - rmse: 3.6747 - val_loss: 26.0658 - val_rmse: 3.6727
# Epoch 276/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.8946 - rmse: 3.9736 - val_loss: 22.6773 - val_rmse: 3.4276
# Epoch 277/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.3577 - rmse: 3.7242 - val_loss: 23.7356 - val_rmse: 3.5149
# Epoch 278/500
# 19/19 [==============================] - 0s 6ms/step - loss: 20.1910 - rmse: 3.4326 - val_loss: 20.7626 - val_rmse: 3.2434
# Epoch 279/500
# 19/19 [==============================] - 0s 6ms/step - loss: 23.5284 - rmse: 3.6443 - val_loss: 22.3626 - val_rmse: 3.4044
# Epoch 280/500
# 19/19 [==============================] - 0s 6ms/step - loss: 23.1416 - rmse: 3.6974 - val_loss: 18.9264 - val_rmse: 3.2069
# Epoch 281/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.8324 - rmse: 3.7836 - val_loss: 23.5910 - val_rmse: 3.5974
# Epoch 282/500
# 19/19 [==============================] - 0s 6ms/step - loss: 38.1119 - rmse: 4.8411 - val_loss: 27.7791 - val_rmse: 3.7277
# Epoch 283/500
# 19/19 [==============================] - 0s 5ms/step - loss: 22.4235 - rmse: 3.6065 - val_loss: 19.3039 - val_rmse: 3.2193
# Epoch 284/500
# 19/19 [==============================] - 0s 6ms/step - loss: 24.5776 - rmse: 3.8761 - val_loss: 21.0741 - val_rmse: 3.4243
# Epoch 285/500
# 19/19 [==============================] - 0s 5ms/step - loss: 22.1671 - rmse: 3.6591 - val_loss: 19.6894 - val_rmse: 3.2025
# Epoch 286/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.9302 - rmse: 3.8770 - val_loss: 20.8645 - val_rmse: 3.5118
# Epoch 287/500
# 19/19 [==============================] - 0s 5ms/step - loss: 31.8300 - rmse: 4.2470 - val_loss: 18.8328 - val_rmse: 3.3609
# Epoch 288/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.9045 - rmse: 3.8195 - val_loss: 26.3603 - val_rmse: 3.8052
# Epoch 289/500
# 19/19 [==============================] - 0s 6ms/step - loss: 23.5723 - rmse: 3.7848 - val_loss: 21.9182 - val_rmse: 3.5475
# Epoch 290/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.1661 - rmse: 3.7884 - val_loss: 22.8189 - val_rmse: 3.5335
# Epoch 291/500
# 19/19 [==============================] - 0s 6ms/step - loss: 28.4558 - rmse: 4.1014 - val_loss: 24.2445 - val_rmse: 3.8019
# Epoch 292/500
# 19/19 [==============================] - 0s 6ms/step - loss: 25.3745 - rmse: 3.9587 - val_loss: 24.9582 - val_rmse: 3.7214
# Epoch 293/500
# 19/19 [==============================] - 0s 6ms/step - loss: 27.9732 - rmse: 4.0468 - val_loss: 27.1648 - val_rmse: 3.7697
# Epoch 294/500
# 19/19 [==============================] - 0s 6ms/step - loss: 31.1992 - rmse: 4.3893 - val_loss: 24.5558 - val_rmse: 3.6685
# Epoch 295/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26.9500 - rmse: 4.0635 - val_loss: 23.8457 - val_rmse: 3.5625
# Epoch 296/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26.3847 - rmse: 3.9706 - val_loss: 25.3104 - val_rmse: 3.8523
# Epoch 297/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.5549 - rmse: 3.6588 - val_loss: 23.4046 - val_rmse: 3.6437
# Epoch 298/500
# 19/19 [==============================] - 0s 6ms/step - loss: 27.0754 - rmse: 4.0678 - val_loss: 20.6374 - val_rmse: 3.4001
# Epoch 299/500
# 19/19 [==============================] - 0s 6ms/step - loss: 25.7212 - rmse: 3.9558 - val_loss: 21.3543 - val_rmse: 3.5360
# Epoch 300/500
# 19/19 [==============================] - 0s 6ms/step - loss: 25.7824 - rmse: 3.8247 - val_loss: 21.3732 - val_rmse: 3.4394
# Epoch 301/500
# 19/19 [==============================] - 0s 5ms/step - loss: 17.9783 - rmse: 3.2438 - val_loss: 20.5776 - val_rmse: 3.3972
# Epoch 302/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.8115 - rmse: 3.9115 - val_loss: 20.0590 - val_rmse: 3.4026
# Epoch 303/500
# 19/19 [==============================] - 0s 3ms/step - loss: 26.4434 - rmse: 4.0131 - val_loss: 22.4412 - val_rmse: 3.5373
# Epoch 304/500
# 19/19 [==============================] - 0s 4ms/step - loss: 27.3386 - rmse: 4.0035 - val_loss: 24.1850 - val_rmse: 3.8028
# Epoch 305/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.6357 - rmse: 3.7249 - val_loss: 24.7766 - val_rmse: 3.6309
# Epoch 306/500
# 19/19 [==============================] - 0s 6ms/step - loss: 21.7201 - rmse: 3.5785 - val_loss: 20.0293 - val_rmse: 3.3519
# Epoch 307/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.7161 - rmse: 3.8043 - val_loss: 21.8888 - val_rmse: 3.4898
# Epoch 308/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.5481 - rmse: 3.8759 - val_loss: 18.8750 - val_rmse: 3.2192
# Epoch 309/500
# 19/19 [==============================] - 0s 6ms/step - loss: 25.9162 - rmse: 3.9615 - val_loss: 22.7891 - val_rmse: 3.4794
# Epoch 310/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.3621 - rmse: 3.8517 - val_loss: 20.3770 - val_rmse: 3.2607
# Epoch 311/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.5401 - rmse: 3.9651 - val_loss: 18.6017 - val_rmse: 3.1429
# Epoch 312/500
# 19/19 [==============================] - 0s 6ms/step - loss: 22.9687 - rmse: 3.8613 - val_loss: 18.1711 - val_rmse: 3.0328
# Epoch 313/500
# 19/19 [==============================] - 0s 5ms/step - loss: 19.0435 - rmse: 3.3610 - val_loss: 20.5233 - val_rmse: 3.2399
# Epoch 314/500
# 19/19 [==============================] - 0s 5ms/step - loss: 22.7456 - rmse: 3.5997 - val_loss: 19.6416 - val_rmse: 3.3215
# Epoch 315/500
# 19/19 [==============================] - 0s 5ms/step - loss: 19.9089 - rmse: 3.4361 - val_loss: 20.4326 - val_rmse: 3.3203
# Epoch 316/500
# 19/19 [==============================] - 0s 7ms/step - loss: 21.9700 - rmse: 3.6508 - val_loss: 18.3538 - val_rmse: 3.0132
# Epoch 317/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.6472 - rmse: 4.3331 - val_loss: 20.1145 - val_rmse: 3.2965
# Epoch 318/500
# 19/19 [==============================] - 0s 5ms/step - loss: 20.7015 - rmse: 3.4575 - val_loss: 19.0805 - val_rmse: 3.1188
# Epoch 319/500
# 19/19 [==============================] - 0s 6ms/step - loss: 18.3316 - rmse: 3.2474 - val_loss: 17.0248 - val_rmse: 2.9999
# Epoch 320/500
# 19/19 [==============================] - 0s 7ms/step - loss: 24.8130 - rmse: 3.9156 - val_loss: 16.9756 - val_rmse: 2.9716
# Epoch 321/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.1411 - rmse: 4.0057 - val_loss: 21.1933 - val_rmse: 3.5170
# Epoch 322/500
# 19/19 [==============================] - 0s 4ms/step - loss: 21.8693 - rmse: 3.6606 - val_loss: 20.5669 - val_rmse: 3.3500
# Epoch 323/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.8241 - rmse: 3.6491 - val_loss: 18.5525 - val_rmse: 3.1661
# Epoch 324/500
# 19/19 [==============================] - 0s 5ms/step - loss: 22.6105 - rmse: 3.7139 - val_loss: 19.8185 - val_rmse: 3.2648
# Epoch 325/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.4686 - rmse: 3.7252 - val_loss: 19.0953 - val_rmse: 3.2627
# Epoch 326/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.1360 - rmse: 3.6853 - val_loss: 17.2562 - val_rmse: 3.1184
# Epoch 327/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.5528 - rmse: 3.7791 - val_loss: 18.2114 - val_rmse: 3.1187
# Epoch 328/500
# 19/19 [==============================] - 0s 6ms/step - loss: 21.5802 - rmse: 3.5926 - val_loss: 18.0657 - val_rmse: 3.1411
# Epoch 329/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.2362 - rmse: 3.6101 - val_loss: 19.5061 - val_rmse: 3.2882
# Epoch 330/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.3874 - rmse: 3.8511 - val_loss: 18.3120 - val_rmse: 3.1207
# Epoch 331/500
# 19/19 [==============================] - 0s 6ms/step - loss: 23.3667 - rmse: 3.7574 - val_loss: 19.7893 - val_rmse: 3.3679
# Epoch 332/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.5957 - rmse: 3.8148 - val_loss: 19.2790 - val_rmse: 3.1596
# Epoch 333/500
# 19/19 [==============================] - 0s 5ms/step - loss: 32.7780 - rmse: 4.4963 - val_loss: 26.7262 - val_rmse: 3.7355
# Epoch 334/500
# 19/19 [==============================] - 0s 5ms/step - loss: 20.9167 - rmse: 3.6423 - val_loss: 22.4115 - val_rmse: 3.4250
# Epoch 335/500
# 19/19 [==============================] - 0s 6ms/step - loss: 20.2700 - rmse: 3.4855 - val_loss: 20.4111 - val_rmse: 3.3040
# Epoch 336/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.0990 - rmse: 3.7872 - val_loss: 26.4341 - val_rmse: 3.6896
# Epoch 337/500
# 19/19 [==============================] - 0s 5ms/step - loss: 19.7526 - rmse: 3.3470 - val_loss: 23.1337 - val_rmse: 3.6809
# Epoch 338/500
# 19/19 [==============================] - 0s 5ms/step - loss: 22.6738 - rmse: 3.5631 - val_loss: 19.3038 - val_rmse: 3.2092
# Epoch 339/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.1297 - rmse: 3.7794 - val_loss: 22.3668 - val_rmse: 3.4120
# Epoch 340/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.5560 - rmse: 3.9152 - val_loss: 18.1187 - val_rmse: 3.0974
# Epoch 341/500
# 19/19 [==============================] - 0s 3ms/step - loss: 21.9351 - rmse: 3.4786 - val_loss: 20.8580 - val_rmse: 3.3829
# Epoch 342/500
# 19/19 [==============================] - 0s 3ms/step - loss: 23.0072 - rmse: 3.7659 - val_loss: 19.9960 - val_rmse: 3.4057
# Epoch 343/500
# 19/19 [==============================] - 0s 4ms/step - loss: 20.8831 - rmse: 3.6349 - val_loss: 18.1172 - val_rmse: 3.1241
# Epoch 344/500
# 19/19 [==============================] - 0s 5ms/step - loss: 20.0774 - rmse: 3.2608 - val_loss: 18.7275 - val_rmse: 3.1838
# Epoch 345/500
# 19/19 [==============================] - 0s 5ms/step - loss: 27.6396 - rmse: 4.0859 - val_loss: 18.6748 - val_rmse: 3.0770
# Epoch 346/500
# 19/19 [==============================] - 0s 6ms/step - loss: 25.1426 - rmse: 3.8037 - val_loss: 17.5526 - val_rmse: 2.9698
# Epoch 347/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.7518 - rmse: 4.0150 - val_loss: 20.2935 - val_rmse: 3.3732
# Epoch 348/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.1801 - rmse: 3.7385 - val_loss: 17.8044 - val_rmse: 3.1574
# Epoch 349/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.7482 - rmse: 3.6697 - val_loss: 20.2297 - val_rmse: 3.2135
# Epoch 350/500
# 19/19 [==============================] - 0s 6ms/step - loss: 22.8963 - rmse: 3.7040 - val_loss: 15.9099 - val_rmse: 2.9113
# Epoch 351/500
# ...
# Epoch 385/500
# 19/19 [==============================] - 0s 6ms/step - loss: 22.2456 - rmse: 3.7344 - val_loss: 16.2795 - val_rmse: 2.7913
# Epoch 386/500
# 19/19 [==============================] - 0s 4ms/step - loss: 18.7338 - rmse: 3.3350 - val_loss: 16.4512 - val_rmse: 2.8672
# Epoch 387/500
# 19/19 [==============================] - 0s 4ms/step - loss: 19.3962 - rmse: 3.4083 - val_loss: 21.9937 - val_rmse: 3.3723
# Epoch 388/500
# 19/19 [==============================] - 0s 4ms/step - loss: 24.3446 - rmse: 3.8284 - val_loss: 19.5174 - val_rmse: 3.3614
# Epoch 389/500
# 19/19 [==============================] - 0s 5ms/step - loss: 22.2901 - rmse: 3.4946 - val_loss: 24.2787 - val_rmse: 3.5893
# Epoch 390/500
# 19/19 [==============================] - 0s 4ms/step - loss: 25.1165 - rmse: 3.8775 - val_loss: 17.5166 - val_rmse: 3.1388
# Epoch 391/500
# 19/19 [==============================] - 0s 5ms/step - loss: 31.0643 - rmse: 4.5089 - val_loss: 20.0450 - val_rmse: 3.2883
# Epoch 392/500
# 19/19 [==============================] - 0s 4ms/step - loss: 23.1687 - rmse: 3.7152 - val_loss: 18.7953 - val_rmse: 3.1195
# Epoch 393/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.6995 - rmse: 3.5496 - val_loss: 21.9376 - val_rmse: 3.4321
# Epoch 394/500
# 19/19 [==============================] - 0s 4ms/step - loss: 19.3010 - rmse: 3.4310 - val_loss: 18.5952 - val_rmse: 3.2107
# Epoch 395/500
# 19/19 [==============================] - 0s 4ms/step - loss: 26.2945 - rmse: 3.9540 - val_loss: 24.5052 - val_rmse: 3.7825
# Epoch 396/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.5440 - rmse: 3.5173 - val_loss: 24.5814 - val_rmse: 3.6544
# Epoch 397/500
# 19/19 [==============================] - 0s 5ms/step - loss: 22.2509 - rmse: 3.6292 - val_loss: 25.6290 - val_rmse: 3.6920
# Epoch 398/500
# 19/19 [==============================] - 0s 4ms/step - loss: 21.4534 - rmse: 3.5674 - val_loss: 20.1869 - val_rmse: 3.4179
# Epoch 399/500
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2585 - rmse: 3.1812 - val_loss: 23.4831 - val_rmse: 3.5133
# Epoch 400/500
# 19/19 [==============================] - 0s 4ms/step - loss: 18.4796 - rmse: 3.3199 - val_loss: 18.6318 - val_rmse: 3.0177
# Epoch 401/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.9414 - rmse: 3.4870 - val_loss: 25.9030 - val_rmse: 3.5407
# Epoch 402/500
# 19/19 [==============================] - 0s 5ms/step - loss: 20.5762 - rmse: 3.5887 - val_loss: 18.4559 - val_rmse: 2.9503
# Epoch 403/500
# 19/19 [==============================] - 0s 3ms/step - loss: 23.3069 - rmse: 3.7886 - val_loss: 20.2524 - val_rmse: 3.2006
# Epoch 404/500
# 19/19 [==============================] - 0s 3ms/step - loss: 20.4560 - rmse: 3.3779 - val_loss: 26.3997 - val_rmse: 3.6651
# Epoch 405/500
# 19/19 [==============================] - 0s 3ms/step - loss: 23.0634 - rmse: 3.6873 - val_loss: 20.8619 - val_rmse: 3.2645
# Epoch 406/500
# 19/19 [==============================] - 0s 4ms/step - loss: 22.0320 - rmse: 3.7101 - val_loss: 19.2142 - val_rmse: 3.1811
# Epoch 407/500
# 19/19 [==============================] - 0s 4ms/step - loss: 18.8262 - rmse: 3.1646 - val_loss: 19.9691 - val_rmse: 3.2122
# Epoch 408/500
# 19/19 [==============================] - 0s 4ms/step - loss: 29.1252 - rmse: 4.1619 - val_loss: 19.9288 - val_rmse: 3.2525
# Epoch 409/500
# 19/19 [==============================] - 0s 4ms/step - loss: 23.3604 - rmse: 3.7112 - val_loss: 20.0477 - val_rmse: 3.2016
# Epoch 410/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.5978 - rmse: 4.1852 - val_loss: 19.7115 - val_rmse: 3.1437
# Epoch 411/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.2036 - rmse: 3.8275 - val_loss: 22.0448 - val_rmse: 3.4396
# Epoch 412/500
# 19/19 [==============================] - 0s 3ms/step - loss: 22.5292 - rmse: 3.6903 - val_loss: 26.8895 - val_rmse: 3.8508
# Epoch 413/500
# 19/19 [==============================] - 0s 5ms/step - loss: 16.1314 - rmse: 3.1597 - val_loss: 19.3791 - val_rmse: 3.0605
# Epoch 414/500
# 19/19 [==============================] - 0s 5ms/step - loss: 17.4758 - rmse: 3.1800 - val_loss: 18.9379 - val_rmse: 3.0703
# Epoch 415/500
# 19/19 [==============================] - 0s 3ms/step - loss: 19.7321 - rmse: 3.3921 - val_loss: 20.1201 - val_rmse: 3.2009
# Epoch 416/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.8782 - rmse: 3.8638 - val_loss: 19.6351 - val_rmse: 3.1633
# Epoch 417/500
# 19/19 [==============================] - 0s 4ms/step - loss: 31.5561 - rmse: 4.2900 - val_loss: 21.3509 - val_rmse: 3.2681
# Epoch 418/500
# 19/19 [==============================] - 0s 4ms/step - loss: 35.0587 - rmse: 4.5779 - val_loss: 31.0933 - val_rmse: 4.1632
# Epoch 419/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.8157 - rmse: 3.8627 - val_loss: 28.4079 - val_rmse: 4.0248
# Epoch 420/500
# 19/19 [==============================] - 0s 4ms/step - loss: 23.8491 - rmse: 3.7644 - val_loss: 22.6800 - val_rmse: 3.5069
# Epoch 421/500
# 19/19 [==============================] - 0s 4ms/step - loss: 24.1277 - rmse: 3.8768 - val_loss: 24.8749 - val_rmse: 3.5823
# Epoch 422/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.2366 - rmse: 3.7815 - val_loss: 23.0114 - val_rmse: 3.4945
# Epoch 423/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26.7446 - rmse: 3.4967 - val_loss: 21.1401 - val_rmse: 3.3159
# Epoch 424/500
# 19/19 [==============================] - 0s 5ms/step - loss: 20.4084 - rmse: 3.4925 - val_loss: 25.1953 - val_rmse: 3.6071
# Epoch 425/500
# 19/19 [==============================] - 0s 4ms/step - loss: 19.2511 - rmse: 3.3593 - val_loss: 21.8531 - val_rmse: 3.4082
# Epoch 426/500
# 19/19 [==============================] - 0s 5ms/step - loss: 20.4860 - rmse: 3.4587 - val_loss: 19.7521 - val_rmse: 3.1347
# Epoch 427/500
# 19/19 [==============================] - 0s 3ms/step - loss: 21.2520 - rmse: 3.5297 - val_loss: 28.0253 - val_rmse: 4.0437
# Epoch 428/500
# 19/19 [==============================] - 0s 4ms/step - loss: 17.1155 - rmse: 3.1562 - val_loss: 18.5247 - val_rmse: 3.0825
# Epoch 429/500
# 19/19 [==============================] - 0s 4ms/step - loss: 28.3810 - rmse: 4.0117 - val_loss: 21.9706 - val_rmse: 3.5602
# Epoch 430/500
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2736 - rmse: 3.3371 - val_loss: 19.2955 - val_rmse: 3.2988
# Epoch 431/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.1379 - rmse: 3.5781 - val_loss: 18.0037 - val_rmse: 3.1120
# Epoch 432/500
# 19/19 [==============================] - 0s 4ms/step - loss: 22.1862 - rmse: 3.6240 - val_loss: 21.4975 - val_rmse: 3.4369
# Epoch 433/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.1961 - rmse: 3.8048 - val_loss: 19.0628 - val_rmse: 3.1781
# Epoch 434/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.2109 - rmse: 3.8569 - val_loss: 20.2322 - val_rmse: 3.3048
# Epoch 435/500
# 19/19 [==============================] - 0s 4ms/step - loss: 19.2283 - rmse: 3.3928 - val_loss: 18.0981 - val_rmse: 3.0282
# Epoch 436/500
# 19/19 [==============================] - 0s 5ms/step - loss: 20.9649 - rmse: 3.4926 - val_loss: 19.1108 - val_rmse: 3.2270
# Epoch 437/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.7147 - rmse: 3.8187 - val_loss: 18.9233 - val_rmse: 3.2279
# Epoch 438/500
# 19/19 [==============================] - 0s 4ms/step - loss: 18.9622 - rmse: 3.3467 - val_loss: 19.3267 - val_rmse: 3.1879
# Epoch 439/500
# 19/19 [==============================] - 0s 5ms/step - loss: 15.5303 - rmse: 3.0883 - val_loss: 17.8726 - val_rmse: 2.9967
# Epoch 440/500
# 19/19 [==============================] - 0s 5ms/step - loss: 15.2025 - rmse: 2.9749 - val_loss: 16.8557 - val_rmse: 3.0213
# Epoch 441/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.5086 - rmse: 3.6558 - val_loss: 17.2393 - val_rmse: 2.9924
# Epoch 442/500
# 19/19 [==============================] - 0s 4ms/step - loss: 18.9864 - rmse: 3.3876 - val_loss: 15.7161 - val_rmse: 2.8889
# Epoch 443/500
# 19/19 [==============================] - 0s 5ms/step - loss: 18.5205 - rmse: 3.3324 - val_loss: 19.3383 - val_rmse: 3.2628
# Epoch 444/500
# 19/19 [==============================] - 0s 4ms/step - loss: 21.2148 - rmse: 3.4974 - val_loss: 19.2912 - val_rmse: 3.3256
# Epoch 445/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.9968 - rmse: 3.9246 - val_loss: 18.6625 - val_rmse: 3.1392
# Epoch 446/500
# 19/19 [==============================] - 0s 5ms/step - loss: 19.6015 - rmse: 3.3580 - val_loss: 16.8999 - val_rmse: 3.0930
# Epoch 447/500
# 19/19 [==============================] - 0s 4ms/step - loss: 18.7314 - rmse: 3.2702 - val_loss: 18.1835 - val_rmse: 3.0864
# Epoch 448/500
# 19/19 [==============================] - 0s 5ms/step - loss: 24.0762 - rmse: 3.6888 - val_loss: 17.5922 - val_rmse: 3.0095
# Epoch 449/500
# 19/19 [==============================] - 0s 3ms/step - loss: 21.4540 - rmse: 3.5556 - val_loss: 18.0276 - val_rmse: 3.1261
# Epoch 450/500
# 19/19 [==============================] - 0s 4ms/step - loss: 19.1081 - rmse: 3.2883 - val_loss: 18.7493 - val_rmse: 3.0766
# Epoch 451/500
# 19/19 [==============================] - 0s 4ms/step - loss: 31.1411 - rmse: 4.3658 - val_loss: 19.2231 - val_rmse: 3.1662
# Epoch 452/500
# 19/19 [==============================] - 0s 5ms/step - loss: 22.2650 - rmse: 3.7169 - val_loss: 20.4355 - val_rmse: 3.1938
# Epoch 453/500
# 19/19 [==============================] - 0s 5ms/step - loss: 17.4085 - rmse: 3.1652 - val_loss: 20.8993 - val_rmse: 3.2988
# Epoch 454/500
# 19/19 [==============================] - 0s 4ms/step - loss: 22.5072 - rmse: 3.6353 - val_loss: 26.5991 - val_rmse: 3.6829
# Epoch 455/500
# 19/19 [==============================] - 0s 4ms/step - loss: 24.2598 - rmse: 3.7104 - val_loss: 24.6766 - val_rmse: 3.5962
# Epoch 456/500
# 19/19 [==============================] - 0s 4ms/step - loss: 23.2018 - rmse: 3.6283 - val_loss: 19.6183 - val_rmse: 3.2400
# Epoch 457/500
# 19/19 [==============================] - 0s 4ms/step - loss: 18.7310 - rmse: 3.3614 - val_loss: 18.5449 - val_rmse: 3.0943
# Epoch 458/500
# 19/19 [==============================] - 0s 4ms/step - loss: 22.5815 - rmse: 3.6431 - val_loss: 18.2598 - val_rmse: 3.0701
# Epoch 459/500
# 19/19 [==============================] - 0s 5ms/step - loss: 20.1734 - rmse: 3.5187 - val_loss: 19.9754 - val_rmse: 3.2805
# Epoch 460/500
# 19/19 [==============================] - 0s 4ms/step - loss: 21.3156 - rmse: 3.4995 - val_loss: 22.7936 - val_rmse: 3.5969
# Epoch 461/500
# 19/19 [==============================] - 0s 4ms/step - loss: 25.0660 - rmse: 3.9051 - val_loss: 20.9818 - val_rmse: 3.4200
# Epoch 462/500
# 19/19 [==============================] - 0s 4ms/step - loss: 14.3677 - rmse: 2.9612 - val_loss: 20.8830 - val_rmse: 3.3056
# Epoch 463/500
# 19/19 [==============================] - 0s 4ms/step - loss: 19.7128 - rmse: 3.4582 - val_loss: 21.5899 - val_rmse: 3.2787
# Epoch 464/500
# 19/19 [==============================] - 0s 5ms/step - loss: 15.4853 - rmse: 2.9680 - val_loss: 20.5879 - val_rmse: 3.1712
# Epoch 465/500
# 19/19 [==============================] - 0s 5ms/step - loss: 21.3713 - rmse: 3.3256 - val_loss: 22.3842 - val_rmse: 3.4173
# Epoch 466/500
# 19/19 [==============================] - 0s 4ms/step - loss: 20.8996 - rmse: 3.5873 - val_loss: 19.3888 - val_rmse: 3.1871
# Epoch 467/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.6284 - rmse: 3.7863 - val_loss: 19.3128 - val_rmse: 3.0830
# Epoch 468/500
# 19/19 [==============================] - 0s 4ms/step - loss: 18.6651 - rmse: 3.3839 - val_loss: 19.2873 - val_rmse: 3.1458
# Epoch 469/500
# 19/19 [==============================] - 0s 4ms/step - loss: 18.1809 - rmse: 3.4045 - val_loss: 22.9289 - val_rmse: 3.4260
# Epoch 470/500
# 19/19 [==============================] - 0s 3ms/step - loss: 28.6604 - rmse: 4.1055 - val_loss: 20.1393 - val_rmse: 3.2953
# Epoch 471/500
# 19/19 [==============================] - 0s 3ms/step - loss: 26.0918 - rmse: 3.9386 - val_loss: 19.1327 - val_rmse: 3.0386
# Epoch 472/500
# 19/19 [==============================] - 0s 3ms/step - loss: 21.2847 - rmse: 3.5443 - val_loss: 21.4730 - val_rmse: 3.3880
# Epoch 473/500
# 19/19 [==============================] - 0s 3ms/step - loss: 19.4186 - rmse: 3.2973 - val_loss: 18.2551 - val_rmse: 3.0878
# Epoch 474/500
# 19/19 [==============================] - 0s 4ms/step - loss: 19.6524 - rmse: 3.2942 - val_loss: 18.3175 - val_rmse: 3.0106
# Epoch 475/500
# 19/19 [==============================] - 0s 4ms/step - loss: 25.1775 - rmse: 3.8521 - val_loss: 19.7606 - val_rmse: 3.1767
# Epoch 476/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29.8904 - rmse: 4.1575 - val_loss: 21.9058 - val_rmse: 3.2950
# Epoch 477/500
# 19/19 [==============================] - 0s 4ms/step - loss: 19.1041 - rmse: 3.4328 - val_loss: 20.8251 - val_rmse: 3.2460
# Epoch 478/500
# 19/19 [==============================] - 0s 4ms/step - loss: 23.7547 - rmse: 3.7226 - val_loss: 19.7312 - val_rmse: 3.2331
# Epoch 479/500
# 19/19 [==============================] - 0s 4ms/step - loss: 19.6956 - rmse: 3.4079 - val_loss: 21.5979 - val_rmse: 3.4354
# Epoch 480/500
# 19/19 [==============================] - 0s 4ms/step - loss: 28.3451 - rmse: 4.0495 - val_loss: 29.5789 - val_rmse: 4.0745
# Epoch 481/500
# 19/19 [==============================] - 0s 4ms/step - loss: 26.5255 - rmse: 3.9720 - val_loss: 43.4796 - val_rmse: 4.7854
# Epoch 482/500
# 19/19 [==============================] - 0s 4ms/step - loss: 26.3422 - rmse: 3.9161 - val_loss: 34.6319 - val_rmse: 4.4670
# Epoch 483/500
# 19/19 [==============================] - 0s 5ms/step - loss: 25.4562 - rmse: 3.8669 - val_loss: 32.8460 - val_rmse: 4.2698
# Epoch 484/500
# 19/19 [==============================] - 0s 4ms/step - loss: 29.1401 - rmse: 4.2648 - val_loss: 31.8503 - val_rmse: 4.2956
# Epoch 485/500
# 19/19 [==============================] - 0s 4ms/step - loss: 26.0875 - rmse: 3.9566 - val_loss: 29.2903 - val_rmse: 4.1246
# Epoch 486/500
# 19/19 [==============================] - 0s 5ms/step - loss: 27.0224 - rmse: 4.0756 - val_loss: 23.9789 - val_rmse: 3.6451
# Epoch 487/500
# 19/19 [==============================] - 0s 4ms/step - loss: 21.3597 - rmse: 3.4931 - val_loss: 23.5017 - val_rmse: 3.5510
# Epoch 488/500
# 19/19 [==============================] - 0s 4ms/step - loss: 21.7453 - rmse: 3.5966 - val_loss: 22.2278 - val_rmse: 3.5828
# Epoch 489/500
# 19/19 [==============================] - 0s 4ms/step - loss: 22.8354 - rmse: 3.7969 - val_loss: 20.9762 - val_rmse: 3.4131
# Epoch 490/500
# 19/19 [==============================] - 0s 5ms/step - loss: 20.2328 - rmse: 3.3754 - val_loss: 21.5774 - val_rmse: 3.4377
# Epoch 491/500
# 19/19 [==============================] - 0s 5ms/step - loss: 22.0457 - rmse: 3.5684 - val_loss: 20.0137 - val_rmse: 3.2848
# Epoch 492/500
# 19/19 [==============================] - 0s 4ms/step - loss: 20.1236 - rmse: 3.4572 - val_loss: 20.1765 - val_rmse: 3.3389
# Epoch 493/500
# 19/19 [==============================] - 0s 4ms/step - loss: 18.4162 - rmse: 3.3931 - val_loss: 21.3975 - val_rmse: 3.3136
# Epoch 494/500
# 19/19 [==============================] - 0s 3ms/step - loss: 22.6687 - rmse: 3.6832 - val_loss: 22.1115 - val_rmse: 3.5932
# Epoch 495/500
# 19/19 [==============================] - 0s 3ms/step - loss: 22.6389 - rmse: 3.6783 - val_loss: 20.4642 - val_rmse: 3.3549
# Epoch 496/500
# 19/19 [==============================] - 0s 3ms/step - loss: 17.5813 - rmse: 3.2369 - val_loss: 19.0675 - val_rmse: 3.2246
# Epoch 497/500
# 19/19 [==============================] - 0s 3ms/step - loss: 18.8366 - rmse: 3.4133 - val_loss: 21.1766 - val_rmse: 3.2489
# Epoch 498/500
# 19/19 [==============================] - 0s 4ms/step - loss: 24.9209 - rmse: 3.8832 - val_loss: 20.6264 - val_rmse: 3.4181
# Epoch 499/500
# 19/19 [==============================] - 0s 4ms/step - loss: 27.1366 - rmse: 4.0347 - val_loss: 28.3321 - val_rmse: 3.7509
# Epoch 500/500
# 19/19 [==============================] - 0s 5ms/step - loss: 23.1548 - rmse: 3.7495 - val_loss: 19.1538 - val_rmse: 3.2295

# %%
# Predicting and Finding R Squared Score
y_predict = model_nn.predict(sc.transform(X_test))
print('Root Mean Squared Error is: ', np.sqrt(mean_squared_error(y_test, y_predict))) 

plt.figure(figsize=(20,5))
plt.plot(list(y_test) ,color = 'red', label = 'Real data',marker='o')
plt.plot(y_predict, color = 'blue', label = 'Predicted data',marker='o')
plt.title('Prediction')
plt.legend()
plt.show()

# Plotting Loss And Root Mean Square Error For both Training And Test Sets
plt.plot(history.history['rmse'])
plt.plot(history.history['val_rmse'])
plt.title('Root Mean Squared Error')
plt.ylabel('rmse')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Root Mean Squared Error is:  4.034781484530675
